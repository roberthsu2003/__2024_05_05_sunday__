# %%
import csv
from csv import DictReader
with open('個股日成交資訊.csv',encoding='utf-8',newline='') as file:
   reader:DictReader = csv.DictReader(file)
   stocks:list[dict] = list(reader)

stocks

# %%
from pydantic import BaseModel,Field,ValidationError,field_validator,RootModel

class Stock(BaseModel):
    證券名稱:str
    成交股數:int
    成交金額:int
    最低價:float
    最高價:float
    成交筆數:int

    @field_validator('最低價','最高價','成交股數','成交金額','成交筆數',mode='before')
    @classmethod
    def for_lowest_highest(cls,value:str) -> str:
        return ''.join(value.split(','))



class Root(RootModel):
    root:list[Stock]

root:Root = Root.model_validate(stocks)

# %%
stock_list:list[dict] = root.model_dump()
stock_list
# Out:
# [{'證券名稱': '元大台灣50',
#   '成交股數': 46790503,
#   '成交金額': 3463425684,
#   '最低價': 72.8,
#   '最高價': 75.25,
#   '成交筆數': 23021},
#  {'證券名稱': '元大中型100',
#   '成交股數': 43172,
#   '成交金額': 1177199,
#   '最低價': 26.75,
#   '最高價': 27.57,
#   '成交筆數': 45},
#  {'證券名稱': '富邦科技',
#   '成交股數': 161425,
#   '成交金額': 9156750,
#   '最低價': 55.35,
#   '最高價': 57.6,
#   '成交筆數': 67},
#  {'證券名稱': '元大電子',
#   '成交股數': 35076,
#   '成交金額': 1163448,
#   '最低價': 32.56,
#   '最高價': 33.61,
#   '成交筆數': 19},
#  {'證券名稱': '元大台商50',
#   '成交股數': 27028,
#   '成交金額': 507569,
#   '最低價': 18.64,
#   '最高價': 19.0,
#   '成交筆數': 13},
#  {'證券名稱': '元大MSCI金融',
#   '成交股數': 62050,
#   '成交金額': 940984,
#   '最低價': 15.0,
#   '最高價': 15.35,
#   '成交筆數': 52},
#  {'證券名稱': '元大高股息',
#   '成交股數': 80530934,
#   '成交金額': 1897973002,
#   '最低價': 23.26,
#   '最高價': 23.82,
#   '成交筆數': 35938},
#  {'證券名稱': '富邦摩台',
#   '成交股數': 20011,
#   '成交金額': 967537,
#   '最低價': 48.35,
#   '最高價': 48.35,
#   '成交筆數': 3},
#  {'證券名稱': '元大寶滬深',
#   '成交股數': 5889414,
#   '成交金額': 103296868,
#   '最低價': 16.9,
#   '最高價': 18.5,
#   '成交筆數': 2346},
#  {'證券名稱': '元大MSCI台灣',
#   '成交股數': 7000,
#   '成交金額': 242470,
#   '最低價': 34.52,
#   '最高價': 34.98,
#   '成交筆數': 5},
#  {'證券名稱': '永豐臺灣加權',
#   '成交股數': 7000,
#   '成交金額': 327600,
#   '最低價': 46.63,
#   '最高價': 47.17,
#   '成交筆數': 5},
#  {'證券名稱': '富邦上証',
#   '成交股數': 2176076,
#   '成交金額': 61949579,
#   '最低價': 28.18,
#   '最高價': 28.58,
#   '成交筆數': 301},
#  {'證券名稱': '元大上證50',
#   '成交股數': 602582,
#   '成交金額': 17703772,
#   '最低價': 29.15,
#   '最高價': 29.6,
#   '成交筆數': 359},
#  {'證券名稱': 'FH滬深',
#   '成交股數': 241250,
#   '成交金額': 5335510,
#   '最低價': 21.93,
#   '最高價': 22.28,
#   '成交筆數': 97},
#  {'證券名稱': '富邦台50',
#   '成交股數': 1366482,
#   '成交金額': 58018386,
#   '最低價': 41.55,
#   '最高價': 43.8,
#   '成交筆數': 867},
#  {'證券名稱': '富邦上証+R',
#   '成交股數': 50000,
#   '成交金額': 333500,
#   '最低價': 6.67,
#   '最高價': 6.67,
#   '成交筆數': 2},
#  {'證券名稱': '元大台灣50正2',
#   '成交股數': 22770009,
#   '成交金額': 725909170,
#   '最低價': 30.66,
#   '最高價': 32.88,
#   '成交筆數': 6348},
#  {'證券名稱': '元大台灣50反1',
#   '成交股數': 307003192,
#   '成交金額': 3890066718,
#   '最低價': 12.49,
#   '最高價': 12.9,
#   '成交筆數': 26210},
#  {'證券名稱': '富邦上証正2',
#   '成交股數': 22471500,
#   '成交金額': 823578024,
#   '最低價': 35.89,
#   '最高價': 37.38,
#   '成交筆數': 4146},
#  {'證券名稱': '富邦上証反1',
#   '成交股數': 11553832,
#   '成交金額': 72528184,
#   '最低價': 6.23,
#   '最高價': 6.35,
#   '成交筆數': 1106},
#  {'證券名稱': '元大S&P黃金',
#   '成交股數': 2074480,
#   '成交金額': 45122284,
#   '最低價': 21.66,
#   '最高價': 21.81,
#   '成交筆數': 679},
#  {'證券名稱': '國泰中國A50',
#   '成交股數': 1812020,
#   '成交金額': 35264078,
#   '最低價': 19.31,
#   '最高價': 19.61,
#   '成交筆數': 522},
#  {'證券名稱': '國泰中國A50+U',
#   '成交股數': 0,
#   '成交金額': 0,
#   '最低價': 0.0,
#   '最高價': 0.0,
#   '成交筆數': 0},
#  {'證券名稱': '元大滬深300正2',
#   '成交股數': 117360971,
#   '成交金額': 1650312234,
#   '最低價': 13.72,
#   '最高價': 14.32,
#   '成交筆數': 12552},
#  {'證券名稱': '元大滬深300反1',
#   '成交股數': 6524000,
#   '成交金額': 83028110,
#   '最低價': 12.6,
#   '最高價': 12.85,
#   '成交筆數': 881},
#  {'證券名稱': '富邦深100',
#   '成交股數': 2842731,
#   '成交金額': 30718102,
#   '最低價': 10.65,
#   '最高價': 10.88,
#   '成交筆數': 290},
#  {'證券名稱': '富邦日本正2',
#   '成交股數': 3151000,
#   '成交金額': 39372470,
#   '最低價': 12.24,
#   '最高價': 12.93,
#   '成交筆數': 723},
#  {'證券名稱': '富邦日本反1',
#   '成交股數': 4330005,
#   '成交金額': 76639029,
#   '最低價': 17.36,
#   '最高價': 18.03,
#   '成交筆數': 978},
#  {'證券名稱': '元大S&P石油',
#   '成交股數': 77488385,
#   '成交金額': 800805843,
#   '最低價': 10.22,
#   '最高價': 10.45,
#   '成交筆數': 13667},
#  {'證券名稱': '群益深証中小',
#   '成交股數': 1486000,
#   '成交金額': 19564510,
#   '最低價': 12.81,
#   '最高價': 13.3,
#   '成交筆數': 494},
#  {'證券名稱': '群益深証中小+R', '成交股數': 0, '成交金額': 0, '最低價': 0.0, '最高價': 0.0, '成交筆數': 0},
#  {'證券名稱': '富邦日本',
#   '成交股數': 143551,
#   '成交金額': 2438596,
#   '最低價': 16.73,
#   '最高價': 17.15,
#   '成交筆數': 38},
#  {'證券名稱': '元大S&P500',
#   '成交股數': 3052106,
#   '成交金額': 68939394,
#   '最低價': 22.38,
#   '最高價': 22.91,
#   '成交筆數': 991},
#  {'證券名稱': '元大S&P500正2',
#   '成交股數': 4152000,
#   '成交金額': 94073210,
#   '最低價': 22.35,
#   '最高價': 23.4,
#   '成交筆數': 835},
#  {'證券名稱': '元大S&P500反1',
#   '成交股數': 10595844,
#   '成交金額': 149013129,
#   '最低價': 13.88,
#   '最高價': 14.2,
#   '成交筆數': 1375},
#  {'證券名稱': 'FH香港正2',
#   '成交股數': 314000,
#   '成交金額': 6348200,
#   '最低價': 19.68,
#   '最高價': 20.7,
#   '成交筆數': 89},
#  {'證券名稱': 'FH香港反1',
#   '成交股數': 1118000,
#   '成交金額': 10717130,
#   '最低價': 9.47,
#   '最高價': 9.68,
#   '成交筆數': 217},
#  {'證券名稱': '富邦印度',
#   '成交股數': 144240,
#   '成交金額': 2472946,
#   '最低價': 16.89,
#   '最高價': 17.61,
#   '成交筆數': 66},
#  {'證券名稱': '富邦印度正2',
#   '成交股數': 1661000,
#   '成交金額': 26245990,
#   '最低價': 15.2,
#   '最高價': 16.42,
#   '成交筆數': 430},
#  {'證券名稱': '富邦印度反1',
#   '成交股數': 1077000,
#   '成交金額': 18607390,
#   '最低價': 16.91,
#   '最高價': 17.72,
#   '成交筆數': 245},
#  {'證券名稱': '國泰中國A50正2',
#   '成交股數': 9188000,
#   '成交金額': 243042750,
#   '最低價': 25.9,
#   '最高價': 26.98,
#   '成交筆數': 2103},
#  {'證券名稱': '國泰中國A50反1',
#   '成交股數': 2297000,
#   '成交金額': 26544820,
#   '最低價': 11.45,
#   '最高價': 11.68,
#   '成交筆數': 252},
#  {'證券名稱': '國泰日經225',
#   '成交股數': 101000,
#   '成交金額': 2134830,
#   '最低價': 20.83,
#   '最高價': 21.14,
#   '成交筆數': 3},
#  {'證券名稱': '國泰日經225+U',
#   '成交股數': 100,
#   '成交金額': 700,
#   '最低價': 7.0,
#   '最高價': 7.0,
#   '成交筆數': 1},
#  {'證券名稱': '元大歐洲50',
#   '成交股數': 72000,
#   '成交金額': 1287470,
#   '最低價': 17.75,
#   '最高價': 18.1,
#   '成交筆數': 27},
#  {'證券名稱': '元大日經225',
#   '成交股數': 5000,
#   '成交金額': 108700,
#   '最低價': 21.5,
#   '最高價': 21.89,
#   '成交筆數': 5},
#  {'證券名稱': '富邦NASDAQ',
#   '成交股數': 287441,
#   '成交金額': 8117878,
#   '最低價': 27.87,
#   '最高價': 28.66,
#   '成交筆數': 177},
#  {'證券名稱': '國泰臺灣加權正2',
#   '成交股數': 1078111,
#   '成交金額': 30450753,
#   '最低價': 27.2,
#   '最高價': 29.02,
#   '成交筆數': 234},
#  {'證券名稱': '國泰臺灣加權反1',
#   '成交股數': 9186005,
#   '成交金額': 132651621,
#   '最低價': 14.24,
#   '最高價': 14.69,
#   '成交筆數': 1308},
#  {'證券名稱': '富邦恒生國企正2',
#   '成交股數': 216000,
#   '成交金額': 4029380,
#   '最低價': 18.15,
#   '最高價': 18.96,
#   '成交筆數': 95},
#  {'證券名稱': '富邦恒生國企反1',
#   '成交股數': 96000,
#   '成交金額': 1454230,
#   '最低價': 14.91,
#   '最高價': 15.19,
#   '成交筆數': 10},
#  {'證券名稱': '國泰美國道瓊',
#   '成交股數': 1585100,
#   '成交金額': 35786960,
#   '最低價': 22.28,
#   '最高價': 22.81,
#   '成交筆數': 407},
#  {'證券名稱': '國泰美國道瓊+U',
#   '成交股數': 100,
#   '成交金額': 748,
#   '最低價': 7.48,
#   '最高價': 7.48,
#   '成交筆數': 1},
#  {'證券名稱': '國泰美國道瓊反1',
#   '成交股數': 16859000,
#   '成交金額': 258411780,
#   '最低價': 15.16,
#   '最高價': 15.6,
#   '成交筆數': 2103},
#  {'證券名稱': '富邦NASDAQ正2',
#   '成交股數': 4569000,
#   '成交金額': 125750710,
#   '最低價': 26.6,
#   '最高價': 28.39,
#   '成交筆數': 1446},
#  {'證券名稱': '富邦NASDAQ反1',
#   '成交股數': 10084100,
#   '成交金額': 127292220,
#   '最低價': 12.51,
#   '最高價': 12.89,
#   '成交筆數': 715},
#  {'證券名稱': '元大S&P原油正2',
#   '成交股數': 364271500,
#   '成交金額': 909166432,
#   '最低價': 2.36,
#   '最高價': 2.7,
#   '成交筆數': 37879},
#  {'證券名稱': '元大S&P原油反1',
#   '成交股數': 7133571,
#   '成交金額': 184148969,
#   '最低價': 25.67,
#   '最高價': 26.06,
#   '成交筆數': 1420},
#  {'證券名稱': '元大S&P黃金反1',
#   '成交股數': 836000,
#   '成交金額': 13549280,
#   '最低價': 16.15,
#   '最高價': 16.31,
#   '成交筆數': 215},
#  {'證券名稱': '富邦臺灣加權正2',
#   '成交股數': 2685000,
#   '成交金額': 33273620,
#   '最低價': 11.94,
#   '最高價': 12.77,
#   '成交筆數': 595},
#  {'證券名稱': '富邦臺灣加權反1',
#   '成交股數': 10766000,
#   '成交金額': 84213600,
#   '最低價': 7.69,
#   '最高價': 7.95,
#   '成交筆數': 1554},
#  {'證券名稱': '富邦VIX',
#   '成交股數': 869273587,
#   '成交金額': 9221523951,
#   '最低價': 10.28,
#   '最高價': 11.3,
#   '成交筆數': 57546},
#  {'證券名稱': '群益NBI生技',
#   '成交股數': 493200,
#   '成交金額': 9496299,
#   '最低價': 19.0,
#   '最高價': 19.7,
#   '成交筆數': 194},
#  {'證券名稱': '元大美債20正2',
#   '成交股數': 660100,
#   '成交金額': 19611936,
#   '最低價': 29.39,
#   '最高價': 29.86,
#   '成交筆數': 186},
#  {'證券名稱': '元大美債20反1',
#   '成交股數': 426000,
#   '成交金額': 5796800,
#   '最低價': 13.56,
#   '最高價': 13.64,
#   '成交筆數': 113},
#  {'證券名稱': '元大美元指數',
#   '成交股數': 38000,
#   '成交金額': 756880,
#   '最低價': 19.82,
#   '最高價': 19.96,
#   '成交筆數': 22},
#  {'證券名稱': '元大美元指數正2',
#   '成交股數': 62000,
#   '成交金額': 1259880,
#   '最低價': 20.23,
#   '最高價': 20.5,
#   '成交筆數': 18},
#  {'證券名稱': '元大美元指數反1',
#   '成交股數': 16000,
#   '成交金額': 287600,
#   '最低價': 17.87,
#   '最高價': 18.03,
#   '成交筆數': 9},
#  {'證券名稱': '群益臺灣加權正2',
#   '成交股數': 403000,
#   '成交金額': 4373240,
#   '最低價': 10.5,
#   '最高價': 11.12,
#   '成交筆數': 112},
#  {'證券名稱': '群益臺灣加權反1',
#   '成交股數': 2298000,
#   '成交金額': 19675030,
#   '最低價': 8.42,
#   '最高價': 8.7,
#   '成交筆數': 265},
#  {'證券名稱': '國泰20年美債正2',
#   '成交股數': 22000,
#   '成交金額': 663230,
#   '最低價': 29.95,
#   '最高價': 30.44,
#   '成交筆數': 11},
#  {'證券名稱': '國泰20年美債反1',
#   '成交股數': 153000,
#   '成交金額': 2132040,
#   '最低價': 13.82,
#   '最高價': 14.03,
#   '成交筆數': 16},
#  {'證券名稱': '兆豐藍籌30',
#   '成交股數': 293150,
#   '成交金額': 5504916,
#   '最低價': 18.45,
#   '最高價': 19.05,
#   '成交筆數': 172},
#  {'證券名稱': '兆豐藍籌30反1',
#   '成交股數': 66000,
#   '成交金額': 1108220,
#   '最低價': 16.7,
#   '最高價': 16.89,
#   '成交筆數': 6},
#  {'證券名稱': '富邦公司治理',
#   '成交股數': 9140240,
#   '成交金額': 173968953,
#   '最低價': 18.72,
#   '最高價': 19.39,
#   '成交筆數': 4044},
#  {'證券名稱': '街口S&P黃豆',
#   '成交股數': 1587470,
#   '成交金額': 21105512,
#   '最低價': 13.19,
#   '最高價': 13.36,
#   '成交筆數': 154},
#  {'證券名稱': '富邦恒生國企',
#   '成交股數': 105058,
#   '成交金額': 1806974,
#   '最低價': 17.19,
#   '最高價': 17.52,
#   '成交筆數': 7},
#  {'證券名稱': '國泰股利精選30',
#   '成交股數': 4367311,
#   '成交金額': 78307902,
#   '最低價': 17.7,
#   '最高價': 18.24,
#   '成交筆數': 2090},
#  {'證券名稱': '國泰標普低波高息',
#   '成交股數': 233000,
#   '成交金額': 3515650,
#   '最低價': 14.95,
#   '最高價': 15.23,
#   '成交筆數': 19},
#  {'證券名稱': '台新MSCI中國',
#   '成交股數': 78000,
#   '成交金額': 1430740,
#   '最低價': 18.15,
#   '最高價': 18.44,
#   '成交筆數': 25},
#  {'證券名稱': '元大S&P日圓正2',
#   '成交股數': 11000,
#   '成交金額': 193660,
#   '最低價': 17.58,
#   '最高價': 17.69,
#   '成交筆數': 10},
#  {'證券名稱': '元大S&P日圓反1',
#   '成交股數': 2000,
#   '成交金額': 39030,
#   '最低價': 19.47,
#   '最高價': 19.56,
#   '成交筆數': 2},
#  {'證券名稱': '元大S&P黃金正2',
#   '成交股數': 9998000,
#   '成交金額': 224045730,
#   '最低價': 22.24,
#   '最高價': 22.53,
#   '成交筆數': 1707},
#  {'證券名稱': '富邦歐洲',
#   '成交股數': 163000,
#   '成交金額': 2349310,
#   '最低價': 14.24,
#   '最高價': 14.53,
#   '成交筆數': 22},
#  {'證券名稱': 'FH彭博高收益債',
#   '成交股數': 401330,
#   '成交金額': 6944992,
#   '最低價': 17.16,
#   '最高價': 17.5,
#   '成交筆數': 118},
#  {'證券名稱': 'FH彭博新興債',
#   '成交股數': 504000,
#   '成交金額': 9802650,
#   '最低價': 19.25,
#   '最高價': 19.63,
#   '成交筆數': 10},
#  {'證券名稱': 'FH富時不動產',
#   '成交股數': 950300,
#   '成交金額': 11354719,
#   '最低價': 11.04,
#   '最高價': 12.96,
#   '成交筆數': 600},
#  {'證券名稱': '元大台灣高息低波',
#   '成交股數': 163000,
#   '成交金額': 4296660,
#   '最低價': 26.0,
#   '最高價': 26.68,
#   '成交筆數': 143},
#  {'證券名稱': '群益道瓊美國地產',
#   '成交股數': 188000,
#   '成交金額': 3043240,
#   '最低價': 16.1,
#   '最高價': 16.35,
#   '成交筆數': 39},
#  {'證券名稱': '街口布蘭特油正2',
#   '成交股數': 195838000,
#   '成交金額': 747541030,
#   '最低價': 3.65,
#   '最高價': 4.01,
#   '成交筆數': 13399},
#  {'證券名稱': '富邦美國特別股',
#   '成交股數': 3873491,
#   '成交金額': 59753095,
#   '最低價': 15.23,
#   '最高價': 15.76,
#   '成交筆數': 895},
#  {'證券名稱': '第一金工業30',
#   '成交股數': 1128999,
#   '成交金額': 18056863,
#   '最低價': 15.65,
#   '最高價': 16.44,
#   '成交筆數': 192},
#  {'證券名稱': '富邦臺灣優質高息',
#   '成交股數': 1112553,
#   '成交金額': 16036820,
#   '最低價': 14.14,
#   '最高價': 14.6,
#   '成交筆數': 468},
#  {'證券名稱': 'FH富時高息低波',
#   '成交股數': 108000,
#   '成交金額': 4219420,
#   '最低價': 38.69,
#   '最高價': 39.7,
#   '成交筆數': 48},
#  {'證券名稱': '國泰RMB短期報酬',
#   '成交股數': 100000,
#   '成交金額': 3844000,
#   '最低價': 38.44,
#   '最高價': 38.44,
#   '成交筆數': 2},
#  {'證券名稱': '富邦臺灣中小',
#   '成交股數': 226442,
#   '成交金額': 3598290,
#   '最低價': 15.7,
#   '最高價': 16.22,
#   '成交筆數': 22},
#  {'證券名稱': '國泰臺韓科技',
#   '成交股數': 172000,
#   '成交金額': 2920460,
#   '最低價': 16.92,
#   '最高價': 17.09,
#   '成交筆數': 19},
#  {'證券名稱': '國泰新興市場',
#   '成交股數': 130000,
#   '成交金額': 1968220,
#   '最低價': 15.08,
#   '最高價': 15.15,
#   '成交筆數': 16},
#  {'證券名稱': '國泰AI+Robo',
#   '成交股數': 1087521,
#   '成交金額': 17830617,
#   '最低價': 16.1,
#   '最高價': 16.85,
#   '成交筆數': 428},
#  {'證券名稱': '元大道瓊白銀',
#   '成交股數': 2968000,
#   '成交金額': 42087300,
#   '最低價': 13.97,
#   '最高價': 14.31,
#   '成交筆數': 448},
#  {'證券名稱': '元大MSCI A股',
#   '成交股數': 763000,
#   '成交金額': 15265450,
#   '最低價': 19.75,
#   '最高價': 20.11,
#   '成交筆數': 133},
#  {'證券名稱': '新光內需收益',
#   '成交股數': 10000,
#   '成交金額': 179750,
#   '最低價': 17.82,
#   '最高價': 18.09,
#   '成交筆數': 6},
#  {'證券名稱': '國泰中國A150',
#   '成交股數': 35038,
#   '成交金額': 702259,
#   '最低價': 19.8,
#   '最高價': 20.31,
#   '成交筆數': 14},
#  {'證券名稱': '中信中國50',
#   '成交股數': 1729253,
#   '成交金額': 36765874,
#   '最低價': 21.09,
#   '最高價': 21.41,
#   '成交筆數': 901},
#  {'證券名稱': '中信中國50正2',
#   '成交股數': 489000,
#   '成交金額': 9578780,
#   '最低價': 19.16,
#   '最高價': 20.0,
#   '成交筆數': 116},
#  {'證券名稱': '統一FANG+',
#   '成交股數': 412000,
#   '成交金額': 8042890,
#   '最低價': 19.1,
#   '最高價': 19.75,
#   '成交筆數': 87},
#  {'證券名稱': '元大全球AI',
#   '成交股數': 457250,
#   '成交金額': 8898295,
#   '最低價': 19.35,
#   '最高價': 19.7,
#   '成交筆數': 254},
#  {'證券名稱': '街口道瓊銅',
#   '成交股數': 43000,
#   '成交金額': 695380,
#   '最低價': 16.07,
#   '最高價': 16.24,
#   '成交筆數': 12},
#  {'證券名稱': '台新MSCI中國正2',
#   '成交股數': 404000,
#   '成交金額': 3113240,
#   '最低價': 7.6,
#   '最高價': 7.83,
#   '成交筆數': 74},
#  {'證券名稱': 'FH美國金融股',
#   '成交股數': 1000,
#   '成交金額': 16600,
#   '最低價': 16.6,
#   '最高價': 16.6,
#   '成交筆數': 1},
#  {'證券名稱': '國泰北美科技',
#   '成交股數': 105000,
#   '成交金額': 2086320,
#   '最低價': 19.55,
#   '最高價': 20.08,
#   '成交筆數': 16},
#  {'證券名稱': '元大US高息特別股',
#   '成交股數': 212815,
#   '成交金額': 3334828,
#   '最低價': 15.5,
#   '最高價': 15.9,
#   '成交筆數': 94},
#  {'證券名稱': '新光中國政金綠債',
#   '成交股數': 2000,
#   '成交金額': 81540,
#   '最低價': 40.77,
#   '最高價': 40.77,
#   '成交筆數': 2},
#  {'證券名稱': '新光中政金綠債+R',
#   '成交股數': 0,
#   '成交金額': 0,
#   '最低價': 0.0,
#   '最高價': 0.0,
#   '成交筆數': 0},
#  {'證券名稱': '新光投等債15+',
#   '成交股數': 2000,
#   '成交金額': 79200,
#   '最低價': 39.6,
#   '最高價': 39.6,
#   '成交筆數': 2},
#  {'證券名稱': '新光ICE美國權值',
#   '成交股數': 2000,
#   '成交金額': 34700,
#   '最低價': 17.35,
#   '最高價': 17.35,
#   '成交筆數': 2},
#  {'證券名稱': '富邦中証500',
#   '成交股數': 1335641,
#   '成交金額': 24022744,
#   '最低價': 17.67,
#   '最高價': 18.03,
#   '成交筆數': 67},
#  {'證券名稱': 'BP上證50', '成交股數': 0, '成交金額': 0, '最低價': 0.0, '最高價': 0.0, '成交筆數': 0},
#  {'證券名稱': '國泰費城半導體',
#   '成交股數': 1358692,
#   '成交金額': 17916918,
#   '最低價': 12.96,
#   '最高價': 13.4,
#   '成交筆數': 437},
#  {'證券名稱': '元大臺灣ESG永續',
#   '成交股數': 8484709,
#   '成交金額': 157578884,
#   '最低價': 18.29,
#   '最高價': 18.85,
#   '成交筆數': 4133},
#  {'證券名稱': '台新全球AI',
#   '成交股數': 32000,
#   '成交金額': 570450,
#   '最低價': 17.67,
#   '最高價': 18.01,
#   '成交筆數': 20},
#  {'證券名稱': '國泰美國道瓊正2',
#   '成交股數': 36008250,
#   '成交金額': 292061567,
#   '最低價': 7.9,
#   '最高價': 8.38,
#   '成交筆數': 4432},
#  {'證券名稱': '元大全球未來通訊',
#   '成交股數': 9478779,
#   '成交金額': 163572705,
#   '最低價': 16.98,
#   '最高價': 17.55,
#   '成交筆數': 2709},
#  {'證券名稱': '國泰US短期公債',
#   '成交股數': 99000,
#   '成交金額': 3899070,
#   '最低價': 39.35,
#   '最高價': 39.43,
#   '成交筆數': 21},
#  {'證券名稱': '新光Shiller CAPE',
#   '成交股數': 34000,
#   '成交金額': 514230,
#   '最低價': 14.98,
#   '最高價': 15.2,
#   '成交筆數': 6},
#  {'證券名稱': '土銀富邦R1',
#   '成交股數': 404000,
#   '成交金額': 6566650,
#   '最低價': 16.23,
#   '最高價': 16.3,
#   '成交筆數': 30},
#  {'證券名稱': '土銀國泰R1',
#   '成交股數': 795000,
#   '成交金額': 13684380,
#   '最低價': 17.19,
#   '最高價': 17.3,
#   '成交筆數': 220},
#  {'證券名稱': '兆豐新光R1',
#   '成交股數': 41000,
#   '成交金額': 760630,
#   '最低價': 18.5,
#   '最高價': 18.7,
#   '成交筆數': 16},
#  {'證券名稱': '土銀富邦R2',
#   '成交股數': 103000,
#   '成交金額': 1477280,
#   '最低價': 14.23,
#   '最高價': 14.38,
#   '成交筆數': 16},
#  {'證券名稱': '兆豐國泰R2',
#   '成交股數': 360000,
#   '成交金額': 6211190,
#   '最低價': 17.22,
#   '最高價': 17.3,
#   '成交筆數': 25},
#  {'證券名稱': '王道圓滿R1',
#   '成交股數': 49000,
#   '成交金額': 457630,
#   '最低價': 9.31,
#   '最高價': 9.47,
#   '成交筆數': 4},
#  {'證券名稱': '京城樂富R1',
#   '成交股數': 79000,
#   '成交金額': 784970,
#   '最低價': 9.9,
#   '最高價': 10.0,
#   '成交筆數': 21},
#  {'證券名稱': '富邦特選蘋果N',
#   '成交股數': 270000,
#   '成交金額': 1162220,
#   '最低價': 4.25,
#   '最高價': 4.35,
#   '成交筆數': 34},
#  {'證券名稱': '元富新中國N', '成交股數': 0, '成交金額': 0, '最低價': 0.0, '最高價': 0.0, '成交筆數': 0},
#  {'證券名稱': '兆豐電菁英30N',
#   '成交股數': 4000,
#   '成交金額': 75480,
#   '最低價': 18.87,
#   '最高價': 18.87,
#   '成交筆數': 1},
#  {'證券名稱': '永豐外資50N', '成交股數': 0, '成交金額': 0, '最低價': 0.0, '最高價': 0.0, '成交筆數': 0},
#  {'證券名稱': '永昌中小300N', '成交股數': 0, '成交金額': 0, '最低價': 0.0, '最高價': 0.0, '成交筆數': 0},
#  {'證券名稱': '凱基臺灣500N', '成交股數': 0, '成交金額': 0, '最低價': 0.0, '最高價': 0.0, '成交筆數': 0},
#  {'證券名稱': '元大特股高息N',
#   '成交股數': 52000,
#   '成交金額': 509380,
#   '最低價': 9.77,
#   '最高價': 9.82,
#   '成交筆數': 19},
#  {'證券名稱': '統一微波高息20N',
#   '成交股數': 16000,
#   '成交金額': 65760,
#   '最低價': 4.11,
#   '最高價': 4.11,
#   '成交筆數': 4},
#  {'證券名稱': '富邦行動通訊N',
#   '成交股數': 1816000,
#   '成交金額': 7159580,
#   '最低價': 3.84,
#   '最高價': 3.98,
#   '成交筆數': 172},
#  {'證券名稱': '台泥',
#   '成交股數': 36467777,
#   '成交金額': 1343606922,
#   '最低價': 36.0,
#   '最高價': 37.5,
#   '成交筆數': 15058},
#  {'證券名稱': '台泥乙特',
#   '成交股數': 86195,
#   '成交金額': 4604393,
#   '最低價': 53.1,
#   '最高價': 53.8,
#   '成交筆數': 52},
#  {'證券名稱': '亞泥',
#   '成交股數': 10728627,
#   '成交金額': 408137154,
#   '最低價': 37.5,
#   '最高價': 38.75,
#   '成交筆數': 5016},
#  {'證券名稱': '嘉泥',
#   '成交股數': 1748006,
#   '成交金額': 26519790,
#   '最低價': 14.85,
#   '最高價': 15.5,
#   '成交筆數': 1004},
#  {'證券名稱': '環泥',
#   '成交股數': 551863,
#   '成交金額': 8360926,
#   '最低價': 15.0,
#   '最高價': 15.4,
#   '成交筆數': 345},
#  {'證券名稱': '幸福',
#   '成交股數': 207000,
#   '成交金額': 1220120,
#   '最低價': 5.66,
#   '最高價': 6.0,
#   '成交筆數': 110},
#  {'證券名稱': '信大',
#   '成交股數': 298100,
#   '成交金額': 4359709,
#   '最低價': 14.35,
#   '最高價': 14.8,
#   '成交筆數': 166},
#  {'證券名稱': '東泥',
#   '成交股數': 103000,
#   '成交金額': 1540900,
#   '最低價': 14.5,
#   '最高價': 15.45,
#   '成交筆數': 84},
#  {'證券名稱': '味全',
#   '成交股數': 2010607,
#   '成交金額': 34563135,
#   '最低價': 17.0,
#   '最高價': 17.55,
#   '成交筆數': 836},
#  {'證券名稱': '味王',
#   '成交股數': 112011,
#   '成交金額': 2827847,
#   '最低價': 25.0,
#   '最高價': 25.4,
#   '成交筆數': 93},
#  {'證券名稱': '大成',
#   '成交股數': 2788796,
#   '成交金額': 97820786,
#   '最低價': 34.7,
#   '最高價': 35.85,
#   '成交筆數': 1617},
#  {'證券名稱': '大飲',
#   '成交股數': 77100,
#   '成交金額': 391088,
#   '最低價': 5.01,
#   '最高價': 5.56,
#   '成交筆數': 19},
#  {'證券名稱': '卜蜂',
#   '成交股數': 1061980,
#   '成交金額': 54660056,
#   '最低價': 51.0,
#   '最高價': 52.1,
#   '成交筆數': 799},
#  {'證券名稱': '統一',
#   '成交股數': 18256131,
#   '成交金額': 1156887853,
#   '最低價': 61.9,
#   '最高價': 64.5,
#   '成交筆數': 8307},
#  {'證券名稱': '愛之味',
#   '成交股數': 2184535,
#   '成交金額': 13132909,
#   '最低價': 5.92,
#   '最高價': 6.1,
#   '成交筆數': 813},
#  {'證券名稱': '泰山',
#   '成交股數': 1311243,
#   '成交金額': 25257983,
#   '最低價': 18.8,
#   '最高價': 19.9,
#   '成交筆數': 761},
#  {'證券名稱': '福壽',
#   '成交股數': 174750,
#   '成交金額': 3087036,
#   '最低價': 16.8,
#   '最高價': 18.7,
#   '成交筆數': 129},
#  {'證券名稱': '台榮',
#   '成交股數': 126000,
#   '成交金額': 1184020,
#   '最低價': 9.33,
#   '最高價': 9.6,
#   '成交筆數': 77},
#  {'證券名稱': '福懋油',
#   '成交股數': 90017,
#   '成交金額': 2615045,
#   '最低價': 28.8,
#   '最高價': 29.3,
#   '成交筆數': 82},
#  {'證券名稱': '佳格',
#   '成交股數': 2754013,
#   '成交金額': 147727894,
#   '最低價': 52.6,
#   '最高價': 54.7,
#   '成交筆數': 2160},
#  {'證券名稱': '聯華',
#   '成交股數': 3955634,
#   '成交金額': 126358933,
#   '最低價': 31.75,
#   '最高價': 32.35,
#   '成交筆數': 2589},
#  {'證券名稱': '聯華食',
#   '成交股數': 369641,
#   '成交金額': 12625812,
#   '最低價': 34.05,
#   '最高價': 34.3,
#   '成交筆數': 279},
#  {'證券名稱': '大統益',
#   '成交股數': 197081,
#   '成交金額': 20009762,
#   '最低價': 100.5,
#   '最高價': 102.5,
#   '成交筆數': 265},
#  {'證券名稱': '天仁',
#   '成交股數': 133500,
#   '成交金額': 4401450,
#   '最低價': 32.6,
#   '最高價': 33.3,
#   '成交筆數': 94},
#  {'證券名稱': '黑松',
#   '成交股數': 219307,
#   '成交金額': 6338987,
#   '最低價': 28.75,
#   '最高價': 29.5,
#   '成交筆數': 120},
#  {'證券名稱': '興泰',
#   '成交股數': 50286,
#   '成交金額': 1170119,
#   '最低價': 22.9,
#   '最高價': 23.8,
#   '成交筆數': 46},
#  {'證券名稱': '宏亞',
#   '成交股數': 44256,
#   '成交金額': 465907,
#   '最低價': 10.2,
#   '最高價': 10.7,
#   '成交筆數': 42},
#  {'證券名稱': '鮮活果汁-KY',
#   '成交股數': 171836,
#   '成交金額': 30406800,
#   '最低價': 171.0,
#   '最高價': 181.0,
#   '成交筆數': 255},
#  {'證券名稱': '台塑',
#   '成交股數': 24594228,
#   '成交金額': 1764474498,
#   '最低價': 70.0,
#   '最高價': 74.4,
#   '成交筆數': 13287},
#  {'證券名稱': '南亞',
#   '成交股數': 18968989,
#   '成交金額': 1020676117,
#   '最低價': 51.6,
#   '最高價': 56.5,
#   '成交筆數': 8615},
#  {'證券名稱': '台聚',
#   '成交股數': 1964664,
#   '成交金額': 18926243,
#   '最低價': 9.5,
#   '最高價': 9.75,
#   '成交筆數': 879},
#  {'證券名稱': '華夏',
#   '成交股數': 5992130,
#   '成交金額': 79101440,
#   '最低價': 12.9,
#   '最高價': 14.2,
#   '成交筆數': 3896},
#  {'證券名稱': '三芳',
#   '成交股數': 325443,
#   '成交金額': 5585361,
#   '最低價': 16.65,
#   '最高價': 17.6,
#   '成交筆數': 199},
#  {'證券名稱': '亞聚',
#   '成交股數': 1625727,
#   '成交金額': 21676491,
#   '最低價': 13.05,
#   '最高價': 13.65,
#   '成交筆數': 1110},
#  {'證券名稱': '台達化',
#   '成交股數': 809635,
#   '成交金額': 6240585,
#   '最低價': 7.63,
#   '最高價': 7.8,
#   '成交筆數': 381},
#  {'證券名稱': '台苯',
#   '成交股數': 3498664,
#   '成交金額': 46763514,
#   '最低價': 13.0,
#   '最高價': 13.75,
#   '成交筆數': 1748},
#  {'證券名稱': '國喬',
#   '成交股數': 5084496,
#   '成交金額': 61762873,
#   '最低價': 11.8,
#   '最高價': 12.5,
#   '成交筆數': 2225},
#  {'證券名稱': '國喬特',
#   '成交股數': 45000,
#   '成交金額': 1356300,
#   '最低價': 30.0,
#   '最高價': 30.5,
#   '成交筆數': 29},
#  {'證券名稱': '聯成',
#   '成交股數': 1944225,
#   '成交金額': 15632840,
#   '最低價': 8.0,
#   '最高價': 8.1,
#   '成交筆數': 654},
#  {'證券名稱': '中石化',
#   '成交股數': 24637860,
#   '成交金額': 170957990,
#   '最低價': 6.8,
#   '最高價': 7.08,
#   '成交筆數': 6643},
#  {'證券名稱': '達新',
#   '成交股數': 1437536,
#   '成交金額': 63227739,
#   '最低價': 43.55,
#   '最高價': 44.65,
#   '成交筆數': 926},
#  {'證券名稱': '上曜',
#   '成交股數': 1147850,
#   '成交金額': 9599135,
#   '最低價': 8.2,
#   '最高價': 8.49,
#   '成交筆數': 454},
#  {'證券名稱': '東陽',
#   '成交股數': 1809027,
#   '成交金額': 53436814,
#   '最低價': 29.05,
#   '最高價': 30.2,
#   '成交筆數': 1452},
#  {'證券名稱': '大洋',
#   '成交股數': 362000,
#   '成交金額': 8380700,
#   '最低價': 22.85,
#   '最高價': 23.8,
#   '成交筆數': 202},
#  {'證券名稱': '永裕',
#   '成交股數': 330555,
#   '成交金額': 9598771,
#   '最低價': 28.35,
#   '最高價': 29.85,
#   '成交筆數': 207},
#  {'證券名稱': '地球',
#   '成交股數': 47000,
#   '成交金額': 355210,
#   '最低價': 7.42,
#   '最高價': 8.09,
#   '成交筆數': 31},
#  {'證券名稱': '恆大',
#   '成交股數': 13317989,
#   '成交金額': 506953832,
#   '最低價': 36.5,
#   '最高價': 39.4,
#   '成交筆數': 7272},
#  {'證券名稱': '台化',
#   '成交股數': 20728266,
#   '成交金額': 1312997770,
#   '最低價': 61.4,
#   '最高價': 65.9,
#   '成交筆數': 10629},
#  {'證券名稱': '再生-KY',
#   '成交股數': 662119,
#   '成交金額': 2454552,
#   '最低價': 3.64,
#   '最高價': 3.78,
#   '成交筆數': 305},
#  {'證券名稱': '廣華-KY',
#   '成交股數': 334127,
#   '成交金額': 12556340,
#   '最低價': 35.0,
#   '最高價': 38.85,
#   '成交筆數': 280},
#  {'證券名稱': '昭輝',
#   '成交股數': 255000,
#   '成交金額': 8523500,
#   '最低價': 32.7,
#   '最高價': 34.25,
#   '成交筆數': 215},
#  {'證券名稱': '勝悅-KY',
#   '成交股數': 536577,
#   '成交金額': 4602518,
#   '最低價': 8.05,
#   '最高價': 8.98,
#   '成交筆數': 299},
#  {'證券名稱': '富林-KY',
#   '成交股數': 8020,
#   '成交金額': 465665,
#   '最低價': 56.7,
#   '最高價': 59.1,
#   '成交筆數': 21},
#  {'證券名稱': '遠東新',
#   '成交股數': 11750252,
#   '成交金額': 264417935,
#   '最低價': 22.1,
#   '最高價': 22.8,
#   '成交筆數': 4268},
#  {'證券名稱': '新纖',
#   '成交股數': 3471517,
#   '成交金額': 33607977,
#   '最低價': 9.62,
#   '最高價': 9.8,
#   '成交筆數': 1265},
#  {'證券名稱': '南染',
#   '成交股數': 41563,
#   '成交金額': 1146212,
#   '最低價': 27.5,
#   '最高價': 27.85,
#   '成交筆數': 23},
#  {'證券名稱': '宏洲',
#   '成交股數': 99049,
#   '成交金額': 656037,
#   '最低價': 6.5,
#   '最高價': 6.7,
#   '成交筆數': 37},
#  {'證券名稱': '東和',
#   '成交股數': 154031,
#   '成交金額': 848724,
#   '最低價': 5.43,
#   '最高價': 5.55,
#   '成交筆數': 80},
#  {'證券名稱': '廣豐',
#   '成交股數': 230791,
#   '成交金額': 2324459,
#   '最低價': 10.0,
#   '最高價': 10.2,
#   '成交筆數': 166},
#  {'證券名稱': '嘉裕',
#   '成交股數': 380090,
#   '成交金額': 2843976,
#   '最低價': 7.37,
#   '最高價': 7.71,
#   '成交筆數': 184},
#  {'證券名稱': '東華',
#   '成交股數': 1039,
#   '成交金額': 7205,
#   '最低價': 6.96,
#   '最高價': 6.96,
#   '成交筆數': 10},
#  {'證券名稱': '新紡',
#   '成交股數': 47001,
#   '成交金額': 1743737,
#   '最低價': 36.2,
#   '最高價': 37.45,
#   '成交筆數': 47},
#  {'證券名稱': '利華',
#   '成交股數': 71800,
#   '成交金額': 642550,
#   '最低價': 8.72,
#   '最高價': 9.08,
#   '成交筆數': 43},
#  {'證券名稱': '大魯閣',
#   '成交股數': 318000,
#   '成交金額': 1233800,
#   '最低價': 3.71,
#   '最高價': 4.0,
#   '成交筆數': 112},
#  {'證券名稱': '福懋',
#   '成交股數': 3846836,
#   '成交金額': 111187322,
#   '最低價': 28.6,
#   '最高價': 29.35,
#   '成交筆數': 2791},
#  {'證券名稱': '中福',
#   '成交股數': 431009,
#   '成交金額': 2979227,
#   '最低價': 6.78,
#   '最高價': 7.02,
#   '成交筆數': 174},
#  {'證券名稱': '華友聯',
#   '成交股數': 148697,
#   '成交金額': 5096272,
#   '最低價': 33.85,
#   '最高價': 35.5,
#   '成交筆數': 124},
#  {'證券名稱': '勤益控',
#   '成交股數': 421250,
#   '成交金額': 7609200,
#   '最低價': 17.85,
#   '最高價': 18.45,
#   '成交筆數': 190},
#  {'證券名稱': '裕豐',
#   '成交股數': 21792,
#   '成交金額': 233163,
#   '最低價': 10.6,
#   '最高價': 10.8,
#   '成交筆數': 14},
#  {'證券名稱': '中和',
#   '成交股數': 392000,
#   '成交金額': 11515950,
#   '最低價': 28.6,
#   '最高價': 30.5,
#   '成交筆數': 206},
#  {'證券名稱': '南紡',
#   '成交股數': 1634251,
#   '成交金額': 13110823,
#   '最低價': 8.0,
#   '最高價': 8.11,
#   '成交筆數': 641},
#  {'證券名稱': '大東',
#   '成交股數': 182054,
#   '成交金額': 1119921,
#   '最低價': 6.0,
#   '最高價': 6.38,
#   '成交筆數': 122},
#  {'證券名稱': '名軒',
#   '成交股數': 341466,
#   '成交金額': 5161208,
#   '最低價': 14.85,
#   '最高價': 15.4,
#   '成交筆數': 198},
#  {'證券名稱': '立益',
#   '成交股數': 90893,
#   '成交金額': 796926,
#   '最低價': 8.5,
#   '最高價': 8.95,
#   '成交筆數': 30},
#  {'證券名稱': '力麗',
#   '成交股數': 1955488,
#   '成交金額': 12922608,
#   '最低價': 6.55,
#   '最高價': 6.69,
#   '成交筆數': 667},
#  {'證券名稱': '大宇',
#   '成交股數': 247356,
#   '成交金額': 1524358,
#   '最低價': 6.05,
#   '最高價': 6.21,
#   '成交筆數': 61},
#  {'證券名稱': '宏和',
#   '成交股數': 371045,
#   '成交金額': 7787858,
#   '最低價': 20.0,
#   '最高價': 21.45,
#   '成交筆數': 195},
#  {'證券名稱': '力鵬',
#   '成交股數': 1104212,
#   '成交金額': 5517460,
#   '最低價': 4.96,
#   '最高價': 5.02,
#   '成交筆數': 364},
#  {'證券名稱': '佳和',
#   '成交股數': 1032278,
#   '成交金額': 10294873,
#   '最低價': 9.93,
#   '最高價': 10.3,
#   '成交筆數': 249},
#  {'證券名稱': '年興',
#   '成交股數': 473017,
#   '成交金額': 7651222,
#   '最低價': 15.9,
#   '最高價': 16.7,
#   '成交筆數': 328},
#  {'證券名稱': '宏益',
#   '成交股數': 611159,
#   '成交金額': 10136800,
#   '最低價': 16.3,
#   '最高價': 16.85,
#   '成交筆數': 330},
#  {'證券名稱': '大將',
#   '成交股數': 43009,
#   '成交金額': 285431,
#   '最低價': 6.55,
#   '最高價': 6.82,
#   '成交筆數': 37},
#  {'證券名稱': '台富',
#   '成交股數': 154000,
#   '成交金額': 1048230,
#   '最低價': 6.7,
#   '最高價': 6.89,
#   '成交筆數': 75},
#  {'證券名稱': '集盛',
#   '成交股數': 1547503,
#   '成交金額': 7723374,
#   '最低價': 4.93,
#   '最高價': 5.1,
#   '成交筆數': 517},
#  {'證券名稱': '怡華',
#   '成交股數': 32000,
#   '成交金額': 204090,
#   '最低價': 6.25,
#   '最高價': 6.6,
#   '成交筆數': 21},
#  {'證券名稱': '宜進',
#   '成交股數': 622000,
#   '成交金額': 6325650,
#   '最低價': 10.1,
#   '最高價': 10.3,
#   '成交筆數': 254},
#  {'證券名稱': '聯發',
#   '成交股數': 186339,
#   '成交金額': 1066033,
#   '最低價': 5.58,
#   '最高價': 5.86,
#   '成交筆數': 79},
#  {'證券名稱': '宏遠',
#   '成交股數': 806898,
#   '成交金額': 4464790,
#   '最低價': 5.42,
#   '最高價': 5.68,
#   '成交筆數': 417},
#  {'證券名稱': '強盛',
#   '成交股數': 360000,
#   '成交金額': 3683700,
#   '最低價': 10.2,
#   '最高價': 10.3,
#   '成交筆數': 173},
#  {'證券名稱': '得力',
#   '成交股數': 1117150,
#   '成交金額': 19957395,
#   '最低價': 17.6,
#   '最高價': 18.1,
#   '成交筆數': 556},
#  {'證券名稱': '偉全',
#   '成交股數': 438000,
#   '成交金額': 6305100,
#   '最低價': 14.15,
#   '最高價': 14.65,
#   '成交筆數': 150},
#  {'證券名稱': '聚隆',
#   '成交股數': 54002,
#   '成交金額': 324412,
#   '最低價': 5.78,
#   '最高價': 6.19,
#   '成交筆數': 40},
#  {'證券名稱': '南緯',
#   '成交股數': 648060,
#   '成交金額': 4393719,
#   '最低價': 6.54,
#   '最高價': 7.13,
#   '成交筆數': 138},
#  {'證券名稱': '昶和',
#   '成交股數': 26000,
#   '成交金額': 226750,
#   '最低價': 8.03,
#   '最高價': 9.08,
#   '成交筆數': 25},
#  {'證券名稱': '大統新創',
#   '成交股數': 14003,
#   '成交金額': 258361,
#   '最低價': 17.25,
#   '最高價': 19.65,
#   '成交筆數': 16},
#  {'證券名稱': '首利',
#   '成交股數': 158736,
#   '成交金額': 259396,
#   '最低價': 1.51,
#   '最高價': 1.66,
#   '成交筆數': 46},
#  {'證券名稱': '三洋紡',
#   '成交股數': 32070,
#   '成交金額': 453788,
#   '最低價': 14.15,
#   '最高價': 14.15,
#   '成交筆數': 25},
#  {'證券名稱': '台南',
#   '成交股數': 348836,
#   '成交金額': 8179401,
#   '最低價': 23.1,
#   '最高價': 24.5,
#   '成交筆數': 236},
#  {'證券名稱': '弘裕',
#   '成交股數': 436058,
#   '成交金額': 3673091,
#   '最低價': 8.25,
#   '最高價': 8.58,
#   '成交筆數': 229},
#  {'證券名稱': '本盟',
#   '成交股數': 10404,
#   '成交金額': 66520,
#   '最低價': 6.41,
#   '最高價': 6.42,
#   '成交筆數': 10},
#  {'證券名稱': '儒鴻',
#   '成交股數': 1989237,
#   '成交金額': 496829192,
#   '最低價': 241.5,
#   '最高價': 263.0,
#   '成交筆數': 1837},
#  {'證券名稱': '聚陽',
#   '成交股數': 4170701,
#   '成交金額': 477658051,
#   '最低價': 112.0,
#   '最高價': 120.0,
#   '成交筆數': 3250},
#  {'證券名稱': '士電',
#   '成交股數': 259456,
#   '成交金額': 10319123,
#   '最低價': 39.15,
#   '最高價': 40.5,
#   '成交筆數': 180},
#  {'證券名稱': '東元',
#   '成交股數': 8387555,
#   '成交金額': 208360320,
#   '最低價': 24.65,
#   '最高價': 25.05,
#   '成交筆數': 2676},
#  {'證券名稱': '正道',
#   '成交股數': 142128,
#   '成交金額': 1423059,
#   '最低價': 9.91,
#   '最高價': 10.25,
#   '成交筆數': 58},
#  {'證券名稱': '永大',
#   '成交股數': 220109,
#   '成交金額': 12568744,
#   '最低價': 56.5,
#   '最高價': 57.8,
#   '成交筆數': 194},
#  {'證券名稱': '瑞利',
#   '成交股數': 112495,
#   '成交金額': 336262,
#   '最低價': 2.85,
#   '最高價': 3.0,
#   '成交筆數': 63},
#  {'證券名稱': '中興電',
#   '成交股數': 2196831,
#   '成交金額': 48065424,
#   '最低價': 21.65,
#   '最高價': 22.1,
#   '成交筆數': 1046},
#  {'證券名稱': '亞力',
#   '成交股數': 1469525,
#   '成交金額': 22119630,
#   '最低價': 14.8,
#   '最高價': 15.35,
#   '成交筆數': 573},
#  {'證券名稱': '力山',
#   '成交股數': 1283394,
#   '成交金額': 58234180,
#   '最低價': 44.5,
#   '最高價': 46.3,
#   '成交筆數': 947},
#  {'證券名稱': '川飛',
#   '成交股數': 118475,
#   '成交金額': 1653237,
#   '最低價': 13.85,
#   '最高價': 14.1,
#   '成交筆數': 39},
#  {'證券名稱': '利奇',
#   '成交股數': 468091,
#   '成交金額': 3022470,
#   '最低價': 6.12,
#   '最高價': 6.64,
#   '成交筆數': 220},
#  {'證券名稱': '華城',
#   '成交股數': 1041994,
#   '成交金額': 23559411,
#   '最低價': 22.05,
#   '最高價': 23.3,
#   '成交筆數': 548},
#  {'證券名稱': '大億',
#   '成交股數': 196062,
#   '成交金額': 10251386,
#   '最低價': 52.0,
#   '最高價': 53.3,
#   '成交筆數': 133},
#  {'證券名稱': '堤維西',
#   '成交股數': 773269,
#   '成交金額': 14027795,
#   '最低價': 18.0,
#   '最高價': 18.6,
#   '成交筆數': 490},
#  {'證券名稱': '耿鼎',
#   '成交股數': 667004,
#   '成交金額': 5747642,
#   '最低價': 8.37,
#   '最高價': 8.78,
#   '成交筆數': 315},
#  {'證券名稱': '江申',
#   '成交股數': 79000,
#   '成交金額': 3190500,
#   '最低價': 40.0,
#   '最高價': 41.0,
#   '成交筆數': 73},
#  {'證券名稱': '日馳',
#   '成交股數': 480955,
#   '成交金額': 7169770,
#   '最低價': 14.55,
#   '最高價': 15.2,
#   '成交筆數': 308},
#  {'證券名稱': '鑽全',
#   '成交股數': 1073294,
#   '成交金額': 39996178,
#   '最低價': 36.5,
#   '最高價': 38.0,
#   '成交筆數': 802},
#  {'證券名稱': '恩德',
#   '成交股數': 413641,
#   '成交金額': 2375536,
#   '最低價': 5.67,
#   '最高價': 5.89,
#   '成交筆數': 310},
#  {'證券名稱': '樂士',
#   '成交股數': 189882,
#   '成交金額': 2162061,
#   '最低價': 10.9,
#   '最高價': 12.65,
#   '成交筆數': 99},
#  {'證券名稱': '亞崴',
#   '成交股數': 46240,
#   '成交金額': 1226012,
#   '最低價': 26.2,
#   '最高價': 26.6,
#   '成交筆數': 40},
#  {'證券名稱': '高林股',
#   '成交股數': 679869,
#   '成交金額': 6634414,
#   '最低價': 9.5,
#   '最高價': 10.2,
#   '成交筆數': 359},
#  {'證券名稱': '勤美',
#   '成交股數': 535915,
#   '成交金額': 12440753,
#   '最低價': 22.9,
#   '最高價': 23.85,
#   '成交筆數': 316},
#  {'證券名稱': '車王電',
#   '成交股數': 161200,
#   '成交金額': 3859700,
#   '最低價': 23.55,
#   '最高價': 25.0,
#   '成交筆數': 125},
#  {'證券名稱': '中宇',
#   '成交股數': 140365,
#   '成交金額': 3903687,
#   '最低價': 27.6,
#   '最高價': 28.25,
#   '成交筆數': 96},
#  {'證券名稱': '和大',
#   '成交股數': 1569958,
#   '成交金額': 138471655,
#   '最低價': 87.6,
#   '最高價': 89.7,
#   '成交筆數': 1078},
#  {'證券名稱': '廣隆',
#   '成交股數': 338900,
#   '成交金額': 43743000,
#   '最低價': 128.0,
#   '最高價': 131.0,
#   '成交筆數': 325},
#  {'證券名稱': '正峰新',
#   '成交股數': 115015,
#   '成交金額': 335276,
#   '最低價': 2.91,
#   '最高價': 3.0,
#   '成交筆數': 39},
#  {'證券名稱': '巨庭',
#   '成交股數': 116642,
#   '成交金額': 1478508,
#   '最低價': 12.3,
#   '最高價': 13.0,
#   '成交筆數': 77},
#  {'證券名稱': '喬福',
#   '成交股數': 384449,
#   '成交金額': 5764934,
#   '最低價': 14.6,
#   '最高價': 15.2,
#   '成交筆數': 175},
#  {'證券名稱': '錩泰',
#   '成交股數': 331089,
#   '成交金額': 8776838,
#   '最低價': 25.75,
#   '最高價': 28.45,
#   '成交筆數': 227},
#  {'證券名稱': '伸興',
#   '成交股數': 378422,
#   '成交金額': 44108083,
#   '最低價': 115.5,
#   '最高價': 118.5,
#   '成交筆數': 298},
#  {'證券名稱': '中砂',
#   '成交股數': 432360,
#   '成交金額': 22025160,
#   '最低價': 50.2,
#   '最高價': 51.5,
#   '成交筆數': 342},
#  {'證券名稱': '倉佑',
#   '成交股數': 168900,
#   '成交金額': 2203731,
#   '最低價': 12.7,
#   '最高價': 13.3,
#   '成交筆數': 98},
#  {'證券名稱': '信錦',
#   '成交股數': 856706,
#   '成交金額': 57451337,
#   '最低價': 66.2,
#   '最高價': 68.4,
#   '成交筆數': 789},
#  {'證券名稱': '程泰',
#   '成交股數': 35000,
#   '成交金額': 1867800,
#   '最低價': 52.2,
#   '最高價': 56.9,
#   '成交筆數': 31},
#  {'證券名稱': '吉茂',
#   '成交股數': 154445,
#   '成交金額': 1504255,
#   '最低價': 9.5,
#   '最高價': 10.5,
#   '成交筆數': 99},
#  {'證券名稱': '永冠-KY',
#   '成交股數': 395000,
#   '成交金額': 19959700,
#   '最低價': 50.2,
#   '最高價': 51.7,
#   '成交筆數': 238},
#  {'證券名稱': '亞德客-KY',
#   '成交股數': 2875736,
#   '成交金額': 1074126715,
#   '最低價': 362.0,
#   '最高價': 384.5,
#   '成交筆數': 2595},
#  {'證券名稱': '英瑞-KY',
#   '成交股數': 1424152,
#   '成交金額': 15856697,
#   '最低價': 10.7,
#   '最高價': 11.6,
#   '成交筆數': 508},
#  {'證券名稱': '岱宇',
#   '成交股數': 1014989,
#   '成交金額': 36584150,
#   '最低價': 35.25,
#   '最高價': 36.6,
#   '成交筆數': 308},
#  {'證券名稱': '華電',
#   '成交股數': 226012,
#   '成交金額': 6314529,
#   '最低價': 26.9,
#   '最高價': 28.5,
#   '成交筆數': 124},
#  {'證券名稱': '聲寶',
#   '成交股數': 1998167,
#   '成交金額': 34498407,
#   '最低價': 16.95,
#   '最高價': 17.65,
#   '成交筆數': 965},
#  {'證券名稱': '華新',
#   '成交股數': 20822385,
#   '成交金額': 238915798,
#   '最低價': 11.0,
#   '最高價': 11.8,
#   '成交筆數': 6333},
#  {'證券名稱': '華榮',
#   '成交股數': 915213,
#   '成交金額': 6315211,
#   '最低價': 6.68,
#   '最高價': 7.06,
#   '成交筆數': 368},
#  {'證券名稱': '大亞',
#   '成交股數': 3096331,
#   '成交金額': 24096854,
#   '最低價': 7.66,
#   '最高價': 7.89,
#   '成交筆數': 1061},
#  {'證券名稱': '中電',
#   '成交股數': 1137250,
#   '成交金額': 13329054,
#   '最低價': 11.45,
#   '最高價': 11.95,
#   '成交筆數': 625},
#  {'證券名稱': '宏泰',
#   '成交股數': 444205,
#   '成交金額': 3876407,
#   '最低價': 8.65,
#   '最高價': 8.8,
#   '成交筆數': 197},
#  {'證券名稱': '三洋電',
#   '成交股數': 121002,
#   '成交金額': 3077000,
#   '最低價': 25.2,
#   '最高價': 26.2,
#   '成交筆數': 92},
#  {'證券名稱': '大山',
#   '成交股數': 194661,
#   '成交金額': 3435217,
#   '最低價': 17.45,
#   '最高價': 17.95,
#   '成交筆數': 100},
#  {'證券名稱': '億泰',
#   '成交股數': 52083,
#   '成交金額': 197857,
#   '最低價': 3.72,
#   '最高價': 3.9,
#   '成交筆數': 38},
#  {'證券名稱': '榮星',
#   '成交股數': 13029,
#   '成交金額': 128575,
#   '最低價': 9.8,
#   '最高價': 9.89,
#   '成交筆數': 15},
#  {'證券名稱': '合機',
#   '成交股數': 251345,
#   '成交金額': 1642844,
#   '最低價': 6.45,
#   '最高價': 6.64,
#   '成交筆數': 115},
#  {'證券名稱': '艾美特-KY',
#   '成交股數': 254913,
#   '成交金額': 5190933,
#   '最低價': 19.8,
#   '最高價': 20.75,
#   '成交筆數': 160},
#  {'證券名稱': '中化',
#   '成交股數': 1839354,
#   '成交金額': 31903722,
#   '最低價': 17.05,
#   '最高價': 17.7,
#   '成交筆數': 925},
#  {'證券名稱': '南僑',
#   '成交股數': 458936,
#   '成交金額': 17829543,
#   '最低價': 38.65,
#   '最高價': 39.15,
#   '成交筆數': 389},
#  {'證券名稱': '葡萄王',
#   '成交股數': 1270221,
#   '成交金額': 264774953,
#   '最低價': 203.5,
#   '最高價': 213.0,
#   '成交筆數': 1118},
#  {'證券名稱': '東鹼',
#   '成交股數': 359624,
#   '成交金額': 7581829,
#   '最低價': 20.9,
#   '最高價': 21.4,
#   '成交筆數': 261},
#  {'證券名稱': '和益',
#   '成交股數': 1463165,
#   '成交金額': 16646226,
#   '最低價': 11.1,
#   '最高價': 11.65,
#   '成交筆數': 528},
#  {'證券名稱': '東聯',
#   '成交股數': 3258219,
#   '成交金額': 49671025,
#   '最低價': 14.75,
#   '最高價': 15.75,
#   '成交筆數': 1654},
#  {'證券名稱': '永光',
#   '成交股數': 1853656,
#   '成交金額': 22657102,
#   '最低價': 11.85,
#   '最高價': 12.75,
#   '成交筆數': 734},
#  {'證券名稱': '興農',
#   '成交股數': 1219363,
#   '成交金額': 20599853,
#   '最低價': 16.85,
#   '最高價': 17.0,
#   '成交筆數': 600},
#  {'證券名稱': '國化',
#   '成交股數': 148533,
#   '成交金額': 2360710,
#   '最低價': 15.55,
#   '最高價': 16.2,
#   '成交筆數': 162},
#  {'證券名稱': '和桐',
#   '成交股數': 6704838,
#   '成交金額': 38441890,
#   '最低價': 5.62,
#   '最高價': 5.88,
#   '成交筆數': 1561},
#  {'證券名稱': '長興',
#   '成交股數': 1882452,
#   '成交金額': 41945948,
#   '最低價': 21.8,
#   '最高價': 22.55,
#   '成交筆數': 829},
#  {'證券名稱': '中纖',
#   '成交股數': 5937580,
#   '成交金額': 31199333,
#   '最低價': 5.2,
#   '最高價': 5.33,
#   '成交筆數': 1871},
#  {'證券名稱': '生達',
#   '成交股數': 431134,
#   '成交金額': 13016872,
#   '最低價': 30.0,
#   '最高價': 30.7,
#   '成交筆數': 294},
#  {'證券名稱': '三晃',
#   '成交股數': 456836,
#   '成交金額': 4003679,
#   '最低價': 8.72,
#   '最高價': 8.88,
#   '成交筆數': 179},
#  {'證券名稱': '台肥',
#   '成交股數': 5810362,
#   '成交金額': 241938802,
#   '最低價': 40.95,
#   '最高價': 42.25,
#   '成交筆數': 2407},
#  {'證券名稱': '中碳',
#   '成交股數': 1009326,
#   '成交金額': 96210657,
#   '最低價': 94.1,
#   '最高價': 97.2,
#   '成交筆數': 958},
#  {'證券名稱': '台硝',
#   '成交股數': 74425,
#   '成交金額': 790865,
#   '最低價': 10.3,
#   '最高價': 10.9,
#   '成交筆數': 56},
#  {'證券名稱': '元禎',
#   '成交股數': 42151,
#   '成交金額': 541035,
#   '最低價': 12.7,
#   '最高價': 13.05,
#   '成交筆數': 40},
#  {'證券名稱': '永記',
#   '成交股數': 94325,
#   '成交金額': 5955908,
#   '最低價': 62.0,
#   '最高價': 64.0,
#   '成交筆數': 87},
#  {'證券名稱': '中華化',
#   '成交股數': 163941,
#   '成交金額': 1416710,
#   '最低價': 8.21,
#   '最高價': 8.97,
#   '成交筆數': 94},
#  {'證券名稱': '花仙子',
#   '成交股數': 596308,
#   '成交金額': 32325736,
#   '最低價': 53.0,
#   '最高價': 55.0,
#   '成交筆數': 483},
#  {'證券名稱': '美吾華',
#   '成交股數': 714014,
#   '成交金額': 8548011,
#   '最低價': 11.85,
#   '最高價': 12.1,
#   '成交筆數': 341},
#  {'證券名稱': '毛寶',
#   '成交股數': 5184533,
#   '成交金額': 137317558,
#   '最低價': 25.3,
#   '最高價': 26.95,
#   '成交筆數': 2508},
#  {'證券名稱': '五鼎',
#   '成交股數': 568645,
#   '成交金額': 11157242,
#   '最低價': 19.15,
#   '最高價': 20.0,
#   '成交筆數': 437},
#  {'證券名稱': '杏輝',
#   '成交股數': 932988,
#   '成交金額': 14966471,
#   '最低價': 15.6,
#   '最高價': 16.6,
#   '成交筆數': 644},
#  {'證券名稱': '日勝化',
#   '成交股數': 66000,
#   '成交金額': 1074550,
#   '最低價': 16.0,
#   '最高價': 16.4,
#   '成交筆數': 27},
#  {'證券名稱': '喬山',
#   '成交股數': 1309284,
#   '成交金額': 61639464,
#   '最低價': 45.7,
#   '最高價': 48.2,
#   '成交筆數': 934},
#  {'證券名稱': '臺鹽',
#   '成交股數': 402725,
#   '成交金額': 11502650,
#   '最低價': 28.4,
#   '最高價': 28.75,
#   '成交筆數': 275},
#  {'證券名稱': '寶齡富錦',
#   '成交股數': 901154,
#   '成交金額': 52234889,
#   '最低價': 55.1,
#   '最高價': 61.0,
#   '成交筆數': 788},
#  {'證券名稱': '中化生',
#   '成交股數': 1910910,
#   '成交金額': 57915265,
#   '最低價': 29.1,
#   '最高價': 31.3,
#   '成交筆數': 1298},
#  {'證券名稱': '勝一',
#   '成交股數': 300158,
#   '成交金額': 25445345,
#   '最低價': 84.0,
#   '最高價': 86.3,
#   '成交筆數': 260},
#  {'證券名稱': '展宇',
#   '成交股數': 109000,
#   '成交金額': 1861450,
#   '最低價': 16.6,
#   '最高價': 17.25,
#   '成交筆數': 39},
#  {'證券名稱': '和康生',
#   '成交股數': 324000,
#   '成交金額': 4918950,
#   '最低價': 14.2,
#   '最高價': 15.6,
#   '成交筆數': 175},
#  {'證券名稱': '科妍',
#   '成交股數': 466111,
#   '成交金額': 19243962,
#   '最低價': 40.75,
#   '最高價': 42.2,
#   '成交筆數': 345},
#  {'證券名稱': '神隆',
#   '成交股數': 6868509,
#   '成交金額': 177666601,
#   '最低價': 24.9,
#   '最高價': 27.0,
#   '成交筆數': 3501},
#  {'證券名稱': '美時',
#   '成交股數': 6731760,
#   '成交金額': 364521280,
#   '最低價': 53.0,
#   '最高價': 58.9,
#   '成交筆數': 4646},
#  {'證券名稱': '台玻',
#   '成交股數': 4152999,
#   '成交金額': 30142392,
#   '最低價': 7.05,
#   '最高價': 7.5,
#   '成交筆數': 1774},
#  {'證券名稱': '寶徠',
#   '成交股數': 18500,
#   '成交金額': 150160,
#   '最低價': 7.6,
#   '最高價': 8.4,
#   '成交筆數': 15},
#  {'證券名稱': '冠軍',
#   '成交股數': 405258,
#   '成交金額': 1807030,
#   '最低價': 4.35,
#   '最高價': 4.57,
#   '成交筆數': 166},
#  {'證券名稱': '潤隆',
#   '成交股數': 646560,
#   '成交金額': 29195799,
#   '最低價': 44.55,
#   '最高價': 46.5,
#   '成交筆數': 397},
#  {'證券名稱': '中釉',
#   '成交股數': 810180,
#   '成交金額': 5757325,
#   '最低價': 7.01,
#   '最高價': 7.21,
#   '成交筆數': 374},
#  {'證券名稱': '和成',
#   '成交股數': 442150,
#   '成交金額': 2656548,
#   '最低價': 5.93,
#   '最高價': 6.09,
#   '成交筆數': 205},
#  {'證券名稱': '凱撒衛',
#   '成交股數': 211968,
#   '成交金額': 5646836,
#   '最低價': 26.1,
#   '最高價': 27.35,
#   '成交筆數': 159},
#  {'證券名稱': '台紙',
#   '成交股數': 1151782,
#   '成交金額': 23107672,
#   '最低價': 20.05,
#   '最高價': 20.15,
#   '成交筆數': 383},
#  {'證券名稱': '士紙',
#   '成交股數': 84087,
#   '成交金額': 2180964,
#   '最低價': 25.45,
#   '最高價': 27.0,
#   '成交筆數': 78},
#  {'證券名稱': '正隆',
#   '成交股數': 7072938,
#   '成交金額': 141175176,
#   '最低價': 19.45,
#   '最高價': 20.65,
#   '成交筆數': 3638},
#  {'證券名稱': '華紙',
#   '成交股數': 1820535,
#   '成交金額': 12244598,
#   '最低價': 6.6,
#   '最高價': 6.79,
#   '成交筆數': 628},
#  {'證券名稱': '寶隆',
#   '成交股數': 459500,
#   '成交金額': 5091350,
#   '最低價': 10.7,
#   '最高價': 11.4,
#   '成交筆數': 254},
#  {'證券名稱': '永豐餘',
#   '成交股數': 4937085,
#   '成交金額': 53572658,
#   '最低價': 10.7,
#   '最高價': 11.25,
#   '成交筆數': 1818},
#  {'證券名稱': '榮成',
#   '成交股數': 15842821,
#   '成交金額': 195447302,
#   '最低價': 11.8,
#   '最高價': 13.0,
#   '成交筆數': 6032},
#  {'證券名稱': '中鋼',
#   '成交股數': 35354413,
#   '成交金額': 686222119,
#   '最低價': 19.25,
#   '最高價': 19.65,
#   '成交筆數': 13030},
#  {'證券名稱': '中鋼特',
#   '成交股數': 101115,
#   '成交金額': 5028624,
#   '最低價': 49.55,
#   '最高價': 50.0,
#   '成交筆數': 70},
#  {'證券名稱': '東和鋼鐵',
#   '成交股數': 2439557,
#   '成交金額': 52839759,
#   '最低價': 21.3,
#   '最高價': 21.95,
#   '成交筆數': 1290},
#  {'證券名稱': '燁興',
#   '成交股數': 197037,
#   '成交金額': 687734,
#   '最低價': 3.41,
#   '最高價': 3.65,
#   '成交筆數': 97},
#  {'證券名稱': '高興昌',
#   '成交股數': 150032,
#   '成交金額': 1829237,
#   '最低價': 12.15,
#   '最高價': 12.25,
#   '成交筆數': 57},
#  {'證券名稱': '第一銅',
#   '成交股數': 359000,
#   '成交金額': 2151990,
#   '最低價': 5.9,
#   '最高價': 6.15,
#   '成交筆數': 154},
#  {'證券名稱': '春源',
#   '成交股數': 607409,
#   '成交金額': 5387877,
#   '最低價': 8.66,
#   '最高價': 9.05,
#   '成交筆數': 303},
#  {'證券名稱': '春雨',
#   '成交股數': 87406,
#   '成交金額': 1490931,
#   '最低價': 16.65,
#   '最高價': 17.4,
#   '成交筆數': 63},
#  {'證券名稱': '中鋼構',
#   '成交股數': 473408,
#   '成交金額': 8831207,
#   '最低價': 18.35,
#   '最高價': 18.95,
#   '成交筆數': 281},
#  {'證券名稱': '中鴻',
#   '成交股數': 6260739,
#   '成交金額': 38717961,
#   '最低價': 6.0,
#   '最高價': 6.31,
#   '成交筆數': 2077},
#  {'證券名稱': '豐興',
#   '成交股數': 1244206,
#   '成交金額': 59284841,
#   '最低價': 47.2,
#   '最高價': 48.55,
#   '成交筆數': 692},
#  {'證券名稱': '官田鋼',
#   '成交股數': 1721402,
#   '成交金額': 10648215,
#   '最低價': 6.0,
#   '最高價': 6.28,
#   '成交筆數': 299},
#  {'證券名稱': '美亞',
#   '成交股數': 397160,
#   '成交金額': 5763753,
#   '最低價': 14.35,
#   '最高價': 14.65,
#   '成交筆數': 168},
#  {'證券名稱': '聚亨',
#   '成交股數': 840328,
#   '成交金額': 3062863,
#   '最低價': 3.6,
#   '最高價': 3.7,
#   '成交筆數': 293},
#  {'證券名稱': '燁輝',
#   '成交股數': 3536165,
#   '成交金額': 28532340,
#   '最低價': 7.99,
#   '最高價': 8.18,
#   '成交筆數': 1224},
#  {'證券名稱': '志聯',
#   '成交股數': 339043,
#   '成交金額': 4198880,
#   '最低價': 12.15,
#   '最高價': 12.55,
#   '成交筆數': 95},
#  {'證券名稱': '千興',
#   '成交股數': 258500,
#   '成交金額': 379123,
#   '最低價': 1.35,
#   '最高價': 1.5,
#   '成交筆數': 45},
#  {'證券名稱': '大成鋼',
#   '成交股數': 6036008,
#   '成交金額': 164799848,
#   '最低價': 26.85,
#   '最高價': 27.7,
#   '成交筆數': 2665},
#  {'證券名稱': '威致',
#   '成交股數': 303887,
#   '成交金額': 2789229,
#   '最低價': 8.76,
#   '最高價': 9.27,
#   '成交筆數': 73},
#  {'證券名稱': '盛餘',
#   '成交股數': 317249,
#   '成交金額': 5024508,
#   '最低價': 15.6,
#   '最高價': 16.0,
#   '成交筆數': 178},
#  {'證券名稱': '彰源',
#   '成交股數': 399662,
#   '成交金額': 3775524,
#   '最低價': 9.39,
#   '最高價': 9.53,
#   '成交筆數': 241},
#  {'證券名稱': '新光鋼',
#   '成交股數': 3476868,
#   '成交金額': 69542278,
#   '最低價': 18.9,
#   '最高價': 21.1,
#   '成交筆數': 1607},
#  {'證券名稱': '新鋼',
#   '成交股數': 161604,
#   '成交金額': 1161234,
#   '最低價': 7.09,
#   '最高價': 7.34,
#   '成交筆數': 59},
#  {'證券名稱': '佳大',
#   '成交股數': 103000,
#   '成交金額': 780880,
#   '最低價': 7.54,
#   '最高價': 7.69,
#   '成交筆數': 34},
#  {'證券名稱': '允強',
#   '成交股數': 968860,
#   '成交金額': 22126771,
#   '最低價': 22.6,
#   '最高價': 23.1,
#   '成交筆數': 499},
#  {'證券名稱': '海光',
#   '成交股數': 318000,
#   '成交金額': 1645870,
#   '最低價': 5.01,
#   '最高價': 5.28,
#   '成交筆數': 123},
#  {'證券名稱': '上銀',
#   '成交股數': 4195409,
#   '成交金額': 859169800,
#   '最低價': 199.0,
#   '最高價': 212.5,
#   '成交筆數': 3404},
#  {'證券名稱': '川湖',
#   '成交股數': 396045,
#   '成交金額': 120176815,
#   '最低價': 295.5,
#   '最高價': 310.0,
#   '成交筆數': 344},
#  {'證券名稱': '橋椿',
#   '成交股數': 408500,
#   '成交金額': 6309425,
#   '最低價': 14.5,
#   '最高價': 15.95,
#   '成交筆數': 206},
#  {'證券名稱': '運錩',
#   '成交股數': 354950,
#   '成交金額': 4288361,
#   '最低價': 11.3,
#   '最高價': 12.7,
#   '成交筆數': 229},
#  {'證券名稱': '南港',
#   '成交股數': 5297099,
#   '成交金額': 214550669,
#   '最低價': 39.55,
#   '最高價': 41.5,
#   '成交筆數': 2114},
#  {'證券名稱': '泰豐',
#   '成交股數': 2702805,
#   '成交金額': 25371851,
#   '最低價': 9.2,
#   '最高價': 9.84,
#   '成交筆數': 810},
#  {'證券名稱': '台橡',
#   '成交股數': 1919776,
#   '成交金額': 29911428,
#   '最低價': 15.05,
#   '最高價': 16.05,
#   '成交筆數': 1181},
#  {'證券名稱': '國際中橡',
#   '成交股數': 3670590,
#   '成交金額': 78404189,
#   '最低價': 21.15,
#   '最高價': 21.7,
#   '成交筆數': 1981},
#  {'證券名稱': '正新',
#   '成交股數': 14962742,
#   '成交金額': 493823736,
#   '最低價': 32.85,
#   '最高價': 33.2,
#   '成交筆數': 4318},
#  {'證券名稱': '建大',
#   '成交股數': 1125259,
#   '成交金額': 30555514,
#   '最低價': 27.05,
#   '最高價': 27.35,
#   '成交筆數': 570},
#  {'證券名稱': '厚生',
#   '成交股數': 1772916,
#   '成交金額': 25102641,
#   '最低價': 13.9,
#   '最高價': 14.5,
#   '成交筆數': 894},
#  {'證券名稱': '南帝',
#   '成交股數': 628664,
#   '成交金額': 15485859,
#   '最低價': 24.35,
#   '最高價': 25.1,
#   '成交筆數': 428},
#  {'證券名稱': '華豐',
#   '成交股數': 549886,
#   '成交金額': 6024407,
#   '最低價': 10.8,
#   '最高價': 11.2,
#   '成交筆數': 160},
#  {'證券名稱': '鑫永銓',
#   '成交股數': 202007,
#   '成交金額': 14186590,
#   '最低價': 68.8,
#   '最高價': 74.5,
#   '成交筆數': 169},
#  {'證券名稱': '六暉-KY',
#   '成交股數': 55598,
#   '成交金額': 1905471,
#   '最低價': 34.1,
#   '最高價': 34.6,
#   '成交筆數': 45},
#  {'證券名稱': '裕隆',
#   '成交股數': 3648029,
#   '成交金額': 59937204,
#   '最低價': 16.05,
#   '最高價': 16.8,
#   '成交筆數': 1621},
#  {'證券名稱': '中華',
#   '成交股數': 913252,
#   '成交金額': 25186722,
#   '最低價': 27.25,
#   '最高價': 28.3,
#   '成交筆數': 531},
#  {'證券名稱': '三陽工業',
#   '成交股數': 2365056,
#   '成交金額': 47098547,
#   '最低價': 19.7,
#   '最高價': 20.05,
#   '成交筆數': 667},
#  {'證券名稱': '和泰車',
#   '成交股數': 1416742,
#   '成交金額': 556158508,
#   '最低價': 372.5,
#   '最高價': 415.0,
#   '成交筆數': 1371},
#  {'證券名稱': '台船',
#   '成交股數': 1226283,
#   '成交金額': 21053661,
#   '最低價': 17.0,
#   '最高價': 17.45,
#   '成交筆數': 643},
#  {'證券名稱': '裕日車',
#   '成交股數': 126201,
#   '成交金額': 26613215,
#   '最低價': 209.0,
#   '最高價': 214.5,
#   '成交筆數': 116},
#  {'證券名稱': '劍麟',
#   '成交股數': 500060,
#   '成交金額': 33992740,
#   '最低價': 66.5,
#   '最高價': 69.5,
#   '成交筆數': 431},
#  {'證券名稱': '為升',
#   '成交股數': 3313482,
#   '成交金額': 362288847,
#   '最低價': 105.5,
#   '最高價': 118.0,
#   '成交筆數': 2466},
#  {'證券名稱': '宇隆',
#   '成交股數': 346657,
#   '成交金額': 16579830,
#   '最低價': 47.25,
#   '最高價': 49.0,
#   '成交筆數': 292},
#  {'證券名稱': '百達-KY',
#   '成交股數': 7000,
#   '成交金額': 107200,
#   '最低價': 15.05,
#   '最高價': 15.8,
#   '成交筆數': 7},
#  {'證券名稱': '英利-KY',
#   '成交股數': 101178,
#   '成交金額': 5120756,
#   '最低價': 49.45,
#   '最高價': 51.8,
#   '成交筆數': 87},
#  {'證券名稱': '宏旭-KY',
#   '成交股數': 25000,
#   '成交金額': 236760,
#   '最低價': 9.32,
#   '最高價': 9.56,
#   '成交筆數': 15},
#  {'證券名稱': '光寶科',
#   '成交股數': 11767747,
#   '成交金額': 464627683,
#   '最低價': 39.1,
#   '最高價': 40.15,
#   '成交筆數': 5797},
#  {'證券名稱': '麗正',
#   '成交股數': 159004,
#   '成交金額': 796281,
#   '最低價': 4.97,
#   '最高價': 5.05,
#   '成交筆數': 79},
#  {'證券名稱': '聯電',
#   '成交股數': 90628139,
#   '成交金額': 1253166496,
#   '最低價': 13.75,
#   '最高價': 14.0,
#   '成交筆數': 11308},
#  {'證券名稱': '全友',
#   '成交股數': 532212,
#   '成交金額': 2114484,
#   '最低價': 3.87,
#   '最高價': 4.07,
#   '成交筆數': 213},
#  {'證券名稱': '台達電',
#   '成交股數': 7516116,
#   '成交金額': 873072456,
#   '最低價': 115.0,
#   '最高價': 119.0,
#   '成交筆數': 4962},
#  {'證券名稱': '金寶',
#   '成交股數': 4981427,
#   '成交金額': 49611869,
#   '最低價': 9.7,
#   '最高價': 10.3,
#   '成交筆數': 1434},
#  {'證券名稱': '華通',
#   '成交股數': 34696866,
#   '成交金額': 951035672,
#   '最低價': 26.1,
#   '最高價': 28.5,
#   '成交筆數': 13731},
#  {'證券名稱': '台揚',
#   '成交股數': 1638542,
#   '成交金額': 22955092,
#   '最低價': 13.4,
#   '最高價': 14.4,
#   '成交筆數': 787},
#  {'證券名稱': '楠梓電',
#   '成交股數': 3998619,
#   '成交金額': 98148835,
#   '最低價': 23.7,
#   '最高價': 25.15,
#   '成交筆數': 2074},
#  {'證券名稱': '鴻海',
#   '成交股數': 76268240,
#   '成交金額': 5378721353,
#   '最低價': 70.0,
#   '最高價': 71.3,
#   '成交筆數': 30314},
#  {'證券名稱': '東訊', '成交股數': 151, '成交金額': 188, '最低價': 0.0, '最高價': 0.0, '成交筆數': 3},
#  {'證券名稱': '中環',
#   '成交股數': 17112877,
#   '成交金額': 114492475,
#   '最低價': 6.48,
#   '最高價': 6.89,
#   '成交筆數': 4206},
#  {'證券名稱': '仁寶',
#   '成交股數': 24219785,
#   '成交金額': 398878966,
#   '最低價': 16.3,
#   '最高價': 16.6,
#   '成交筆數': 6791},
#  {'證券名稱': '國巨',
#   '成交股數': 27465524,
#   '成交金額': 7296200644,
#   '最低價': 250.0,
#   '最高價': 275.0,
#   '成交筆數': 19059},
#  {'證券名稱': '廣宇',
#   '成交股數': 2275221,
#   '成交金額': 36217770,
#   '最低價': 15.75,
#   '最高價': 16.1,
#   '成交筆數': 1167},
#  {'證券名稱': '華泰',
#   '成交股數': 4031031,
#   '成交金額': 36503660,
#   '最低價': 8.9,
#   '最高價': 9.23,
#   '成交筆數': 1607},
#  {'證券名稱': '台積電',
#   '成交股數': 118620643,
#   '成交金額': 31555231792,
#   '最低價': 260.0,
#   '最高價': 272.5,
#   '成交筆數': 53985},
#  {'證券名稱': '精英',
#   '成交股數': 1216022,
#   '成交金額': 10157869,
#   '最低價': 8.3,
#   '最高價': 8.45,
#   '成交筆數': 524},
#  {'證券名稱': '友訊',
#   '成交股數': 5324846,
#   '成交金額': 48537444,
#   '最低價': 8.95,
#   '最高價': 9.33,
#   '成交筆數': 2003},
#  {'證券名稱': '旺宏',
#   '成交股數': 57693817,
#   '成交金額': 1469948875,
#   '最低價': 24.5,
#   '最高價': 26.3,
#   '成交筆數': 20112},
#  {'證券名稱': '光罩',
#   '成交股數': 7186959,
#   '成交金額': 170992498,
#   '最低價': 22.7,
#   '最高價': 24.5,
#   '成交筆數': 3593},
#  {'證券名稱': '光磊',
#   '成交股數': 2974535,
#   '成交金額': 47191882,
#   '最低價': 15.5,
#   '最高價': 16.45,
#   '成交筆數': 1444},
#  {'證券名稱': '茂矽',
#   '成交股數': 8665494,
#   '成交金額': 196081182,
#   '最低價': 21.05,
#   '最高價': 24.2,
#   '成交筆數': 4651},
#  {'證券名稱': '華邦電',
#   '成交股數': 38512699,
#   '成交金額': 448586151,
#   '最低價': 11.25,
#   '最高價': 11.9,
#   '成交筆數': 10318},
#  {'證券名稱': '智邦',
#   '成交股數': 9022798,
#   '成交金額': 1526143170,
#   '最低價': 165.0,
#   '最高價': 172.5,
#   '成交筆數': 5920},
#  {'證券名稱': '聯強',
#   '成交股數': 9600059,
#   '成交金額': 336446884,
#   '最低價': 34.45,
#   '最高價': 35.45,
#   '成交筆數': 3956},
#  {'證券名稱': '海悅',
#   '成交股數': 497341,
#   '成交金額': 22766853,
#   '最低價': 45.0,
#   '最高價': 46.65,
#   '成交筆數': 358},
#  {'證券名稱': '錸德',
#   '成交股數': 4408335,
#   '成交金額': 17249586,
#   '最低價': 3.82,
#   '最高價': 4.0,
#   '成交筆數': 1217},
#  {'證券名稱': '順德',
#   '成交股數': 753100,
#   '成交金額': 29966930,
#   '最低價': 38.4,
#   '最高價': 41.5,
#   '成交筆數': 528},
#  {'證券名稱': '佳世達',
#   '成交股數': 7202151,
#   '成交金額': 110498715,
#   '最低價': 14.95,
#   '最高價': 15.65,
#   '成交筆數': 3300},
#  {'證券名稱': '宏碁',
#   '成交股數': 16568603,
#   '成交金額': 223969477,
#   '最低價': 13.4,
#   '最高價': 13.65,
#   '成交筆數': 5067},
#  {'證券名稱': '鴻準',
#   '成交股數': 5265550,
#   '成交金額': 264382846,
#   '最低價': 49.95,
#   '最高價': 50.9,
#   '成交筆數': 3121},
#  {'證券名稱': '敬鵬',
#   '成交股數': 1177519,
#   '成交金額': 25715208,
#   '最低價': 21.5,
#   '最高價': 22.2,
#   '成交筆數': 777},
#  {'證券名稱': '英業達',
#   '成交股數': 9058383,
#   '成交金額': 180606259,
#   '最低價': 19.6,
#   '最高價': 20.2,
#   '成交筆數': 3362},
#  {'證券名稱': '華碩',
#   '成交股數': 3354908,
#   '成交金額': 619861421,
#   '最低價': 183.0,
#   '最高價': 187.0,
#   '成交筆數': 2380},
#  {'證券名稱': '廷鑫',
#   '成交股數': 577000,
#   '成交金額': 5934630,
#   '最低價': 9.95,
#   '最高價': 10.75,
#   '成交筆數': 246},
#  {'證券名稱': '所羅門',
#   '成交股數': 694617,
#   '成交金額': 10749955,
#   '最低價': 15.1,
#   '最高價': 15.8,
#   '成交筆數': 404},
#  {'證券名稱': '致茂',
#   '成交股數': 3469258,
#   '成交金額': 382723944,
#   '最低價': 107.0,
#   '最高價': 115.0,
#   '成交筆數': 2594},
#  {'證券名稱': '藍天',
#   '成交股數': 728547,
#   '成交金額': 19754663,
#   '最低價': 26.75,
#   '最高價': 27.4,
#   '成交筆數': 441},
#  {'證券名稱': '矽統',
#   '成交股數': 2970192,
#   '成交金額': 17125057,
#   '最低價': 5.54,
#   '最高價': 5.96,
#   '成交筆數': 1166},
#  {'證券名稱': '倫飛',
#   '成交股數': 168123,
#   '成交金額': 263562,
#   '最低價': 1.53,
#   '最高價': 1.6,
#   '成交筆數': 236},
#  {'證券名稱': '昆盈',
#   '成交股數': 1164612,
#   '成交金額': 6648137,
#   '最低價': 5.5,
#   '最高價': 5.85,
#   '成交筆數': 365},
#  {'證券名稱': '燿華',
#   '成交股數': 11925889,
#   '成交金額': 210806134,
#   '最低價': 17.1,
#   '最高價': 18.1,
#   '成交筆數': 4515},
#  {'證券名稱': '金像電',
#   '成交股數': 126738996,
#   '成交金額': 2501663661,
#   '最低價': 18.55,
#   '最高價': 20.9,
#   '成交筆數': 37172},
#  {'證券名稱': '菱生',
#   '成交股數': 2451824,
#   '成交金額': 19825407,
#   '最低價': 7.81,
#   '最高價': 8.4,
#   '成交筆數': 1030},
#  {'證券名稱': '大同',
#   '成交股數': 9223956,
#   '成交金額': 170482090,
#   '最低價': 18.0,
#   '最高價': 19.05,
#   '成交筆數': 3793},
#  {'證券名稱': '震旦行',
#   '成交股數': 183327,
#   '成交金額': 14885087,
#   '最低價': 78.2,
#   '最高價': 83.8,
#   '成交筆數': 154},
#  {'證券名稱': '佳能',
#   '成交股數': 611373,
#   '成交金額': 6496509,
#   '最低價': 10.2,
#   '最高價': 10.95,
#   '成交筆數': 319},
#  {'證券名稱': '凱美',
#   '成交股數': 2379630,
#   '成交金額': 68685405,
#   '最低價': 28.05,
#   '最高價': 29.6,
#   '成交筆數': 1549},
#  {'證券名稱': '技嘉',
#   '成交股數': 8594020,
#   '成交金額': 357803550,
#   '最低價': 40.0,
#   '最高價': 43.45,
#   '成交筆數': 4943},
#  {'證券名稱': '微星',
#   '成交股數': 4888748,
#   '成交金額': 370826122,
#   '最低價': 73.2,
#   '最高價': 78.0,
#   '成交筆數': 3219},
#  {'證券名稱': '瑞昱',
#   '成交股數': 5435308,
#   '成交金額': 995527440,
#   '最低價': 179.5,
#   '最高價': 187.0,
#   '成交筆數': 3937},
#  {'證券名稱': '虹光',
#   '成交股數': 147683,
#   '成交金額': 495100,
#   '最低價': 3.31,
#   '最高價': 3.42,
#   '成交筆數': 85},
#  {'證券名稱': '廣達',
#   '成交股數': 12345681,
#   '成交金額': 686311678,
#   '最低價': 55.0,
#   '最高價': 56.3,
#   '成交筆數': 6079},
#  {'證券名稱': '台光電',
#   '成交股數': 5210896,
#   '成交金額': 537576556,
#   '最低價': 100.0,
#   '最高價': 105.5,
#   '成交筆數': 3359},
#  {'證券名稱': '群光',
#   '成交股數': 3330042,
#   '成交金額': 253522791,
#   '最低價': 75.8,
#   '最高價': 76.9,
#   '成交筆數': 1968},
#  {'證券名稱': '精元',
#   '成交股數': 3542657,
#   '成交金額': 88312850,
#   '最低價': 24.05,
#   '最高價': 26.0,
#   '成交筆數': 1596},
#  {'證券名稱': '威盛',
#   '成交股數': 1000463,
#   '成交金額': 19681769,
#   '最低價': 18.8,
#   '最高價': 20.55,
#   '成交筆數': 575},
#  {'證券名稱': '云辰',
#   '成交股數': 5057100,
#   '成交金額': 33382309,
#   '最低價': 5.87,
#   '最高價': 6.72,
#   '成交筆數': 1428},
#  {'證券名稱': '正崴',
#   '成交股數': 2891806,
#   '成交金額': 77291152,
#   '最低價': 26.0,
#   '最高價': 27.35,
#   '成交筆數': 1525},
#  {'證券名稱': '億光',
#   '成交股數': 3566380,
#   '成交金額': 86940036,
#   '最低價': 23.5,
#   '最高價': 25.15,
#   '成交筆數': 2069},
#  {'證券名稱': '研華',
#   '成交股數': 2262074,
#   '成交金額': 553208863,
#   '最低價': 235.0,
#   '最高價': 250.0,
#   '成交筆數': 1806},
#  {'證券名稱': '友通',
#   '成交股數': 389760,
#   '成交金額': 23991119,
#   '最低價': 59.7,
#   '最高價': 63.8,
#   '成交筆數': 296},
#  {'證券名稱': '映泰',
#   '成交股數': 8478000,
#   '成交金額': 62888320,
#   '最低價': 6.9,
#   '最高價': 7.6,
#   '成交筆數': 927},
#  {'證券名稱': '凌陽',
#   '成交股數': 1440216,
#   '成交金額': 12040108,
#   '最低價': 8.18,
#   '最高價': 8.56,
#   '成交筆數': 755},
#  {'證券名稱': '毅嘉',
#   '成交股數': 1399993,
#   '成交金額': 14550513,
#   '最低價': 10.1,
#   '最高價': 10.55,
#   '成交筆數': 686},
#  {'證券名稱': '漢唐',
#   '成交股數': 2031207,
#   '成交金額': 299516015,
#   '最低價': 145.0,
#   '最高價': 151.0,
#   '成交筆數': 1571},
#  {'證券名稱': '浩鑫',
#   '成交股數': 1885000,
#   '成交金額': 12579090,
#   '最低價': 6.46,
#   '最高價': 6.75,
#   '成交筆數': 703},
#  {'證券名稱': '國碩',
#   '成交股數': 1507524,
#   '成交金額': 13378370,
#   '最低價': 8.65,
#   '最高價': 9.3,
#   '成交筆數': 716},
#  {'證券名稱': '南亞科',
#   '成交股數': 21734141,
#   '成交金額': 1144418607,
#   '最低價': 50.2,
#   '最高價': 55.9,
#   '成交筆數': 11722},
#  {'證券名稱': '友達',
#   '成交股數': 112842850,
#   '成交金額': 822144252,
#   '最低價': 7.1,
#   '最高價': 7.41,
#   '成交筆數': 20698},
#  {'證券名稱': '中華電',
#   '成交股數': 17985225,
#   '成交金額': 1907565380,
# ...
#   '最高價': 66.4,
#   '成交筆數': 145},
#  {'證券名稱': '致伸',
#   '成交股數': 3936469,
#   '成交金額': 153322656,
#   '最低價': 37.75,
#   '最高價': 40.3,
#   '成交筆數': 2144},
#  {'證券名稱': '事欣科',
#   '成交股數': 549015,
#   '成交金額': 12754111,
#   '最低價': 22.65,
#   '最高價': 23.6,
#   '成交筆數': 320},
#  {'證券名稱': '新唐',
#   '成交股數': 1250085,
#   '成交金額': 38329963,
#   '最低價': 30.2,
#   '最高價': 31.3,
#   '成交筆數': 958},
#  {'證券名稱': '泰鼎-KY',
#   '成交股數': 14505450,
#   '成交金額': 746637798,
#   '最低價': 50.0,
#   '最高價': 52.7,
#   '成交筆數': 9431},
#  {'證券名稱': '燦星網',
#   '成交股數': 192400,
#   '成交金額': 1403833,
#   '最低價': 7.19,
#   '最高價': 7.4,
#   '成交筆數': 97},
#  {'證券名稱': '太極',
#   '成交股數': 2867061,
#   '成交金額': 32202099,
#   '最低價': 10.45,
#   '最高價': 11.9,
#   '成交筆數': 1174},
#  {'證券名稱': '茂林-KY',
#   '成交股數': 6296843,
#   '成交金額': 534211891,
#   '最低價': 80.7,
#   '最高價': 88.0,
#   '成交筆數': 4648},
#  {'證券名稱': '和碩',
#   '成交股數': 8971566,
#   '成交金額': 455337007,
#   '最低價': 50.2,
#   '最高價': 51.7,
#   '成交筆數': 5024},
#  {'證券名稱': '嘉彰',
#   '成交股數': 745260,
#   '成交金額': 20764964,
#   '最低價': 27.55,
#   '最高價': 28.35,
#   '成交筆數': 501},
#  {'證券名稱': '康控-KY',
#   '成交股數': 3680139,
#   '成交金額': 336295447,
#   '最低價': 88.4,
#   '最高價': 93.5,
#   '成交筆數': 2847},
#  {'證券名稱': '凌通',
#   '成交股數': 412708,
#   '成交金額': 10820491,
#   '最低價': 25.95,
#   '最高價': 26.9,
#   '成交筆數': 259},
#  {'證券名稱': '光鋐',
#   '成交股數': 337707,
#   '成交金額': 2795987,
#   '最低價': 8.23,
#   '最高價': 8.39,
#   '成交筆數': 219},
#  {'證券名稱': '臻鼎-KY',
#   '成交股數': 11451605,
#   '成交金額': 944291602,
#   '最低價': 80.0,
#   '最高價': 85.4,
#   '成交筆數': 7498},
#  {'證券名稱': '誠美材',
#   '成交股數': 898155,
#   '成交金額': 3734078,
#   '最低價': 3.9,
#   '最高價': 4.47,
#   '成交筆數': 201},
#  {'證券名稱': '天鈺',
#   '成交股數': 1159901,
#   '成交金額': 25840080,
#   '最低價': 21.35,
#   '最高價': 23.0,
#   '成交筆數': 695},
#  {'證券名稱': '十銓',
#   '成交股數': 8460840,
#   '成交金額': 258549946,
#   '最低價': 29.35,
#   '最高價': 33.25,
#   '成交筆數': 4787},
#  {'證券名稱': '立積',
#   '成交股數': 5348089,
#   '成交金額': 590398667,
#   '最低價': 103.0,
#   '最高價': 116.0,
#   '成交筆數': 3843},
#  {'證券名稱': '佳凌',
#   '成交股數': 1233084,
#   '成交金額': 17250274,
#   '最低價': 13.3,
#   '最高價': 14.6,
#   '成交筆數': 766},
#  {'證券名稱': '眾達-KY',
#   '成交股數': 2662256,
#   '成交金額': 227045000,
#   '最低價': 80.0,
#   '最高價': 90.5,
#   '成交筆數': 1985},
#  {'證券名稱': '榮科',
#   '成交股數': 431000,
#   '成交金額': 5852900,
#   '最低價': 13.1,
#   '最高價': 14.05,
#   '成交筆數': 218},
#  {'證券名稱': '傳奇',
#   '成交股數': 223560,
#   '成交金額': 10188695,
#   '最低價': 44.5,
#   '最高價': 48.4,
#   '成交筆數': 205},
#  {'證券名稱': '鑫禾',
#   '成交股數': 112000,
#   '成交金額': 3451000,
#   '最低價': 30.15,
#   '最高價': 31.7,
#   '成交筆數': 100},
#  {'證券名稱': '三星',
#   '成交股數': 312119,
#   '成交金額': 13933724,
#   '最低價': 43.75,
#   '最高價': 46.0,
#   '成交筆數': 225},
#  {'證券名稱': '訊連',
#   '成交股數': 1510060,
#   '成交金額': 139713807,
#   '最低價': 90.0,
#   '最高價': 97.2,
#   '成交筆數': 1321},
#  {'證券名稱': '科嘉-KY',
#   '成交股數': 1342600,
#   '成交金額': 68214119,
#   '最低價': 49.4,
#   '最高價': 52.2,
#   '成交筆數': 1008},
#  {'證券名稱': '東科-KY',
#   '成交股數': 495000,
#   '成交金額': 10726950,
#   '最低價': 21.2,
#   '最高價': 22.3,
#   '成交筆數': 336},
#  {'證券名稱': '達興材料',
#   '成交股數': 637307,
#   '成交金額': 44774189,
#   '最低價': 68.1,
#   '最高價': 72.4,
#   '成交筆數': 502},
#  {'證券名稱': '乙盛-KY',
#   '成交股數': 999021,
#   '成交金額': 25524043,
#   '最低價': 25.15,
#   '最高價': 26.15,
#   '成交筆數': 597},
#  {'證券名稱': '虹堡',
#   '成交股數': 292100,
#   '成交金額': 4932630,
#   '最低價': 16.25,
#   '最高價': 17.4,
#   '成交筆數': 183},
#  {'證券名稱': '鎧勝-KY',
#   '成交股數': 4509150,
#   '成交金額': 159199060,
#   '最低價': 33.0,
#   '最高價': 36.5,
#   '成交筆數': 2745},
#  {'證券名稱': '祥碩',
#   '成交股數': 1914258,
#   '成交金額': 1329558020,
#   '最低價': 672.0,
#   '最高價': 727.0,
#   '成交筆數': 1848},
#  {'證券名稱': '禾聯碩',
#   '成交股數': 263370,
#   '成交金額': 24073399,
#   '最低價': 90.6,
#   '最高價': 92.8,
#   '成交筆數': 202},
#  {'證券名稱': 'jpp-KY',
#   '成交股數': 68208,
#   '成交金額': 2284726,
#   '最低價': 32.65,
#   '最高價': 35.2,
#   '成交筆數': 50},
#  {'證券名稱': '界霖',
#   '成交股數': 346011,
#   '成交金額': 13055501,
#   '最低價': 36.8,
#   '最高價': 39.0,
#   '成交筆數': 229},
#  {'證券名稱': '豐祥-KY',
#   '成交股數': 136186,
#   '成交金額': 12699498,
#   '最低價': 92.0,
#   '最高價': 94.0,
#   '成交筆數': 114},
#  {'證券名稱': '敦南',
#   '成交股數': 598802,
#   '成交金額': 23432875,
#   '最低價': 38.8,
#   '最高價': 39.6,
#   '成交筆數': 420},
#  {'證券名稱': '中磊',
#   '成交股數': 2028550,
#   '成交金額': 123299200,
#   '最低價': 59.3,
#   '最高價': 61.6,
#   '成交筆數': 1437},
#  {'證券名稱': '崇越',
#   '成交股數': 1361275,
#   '成交金額': 117768075,
#   '最低價': 84.0,
#   '最高價': 88.6,
#   '成交筆數': 1123},
#  {'證券名稱': '瀚宇博',
#   '成交股數': 6222492,
#   '成交金額': 192752850,
#   '最低價': 30.4,
#   '最高價': 31.5,
#   '成交筆數': 2920},
#  {'證券名稱': '松翰',
#   '成交股數': 6854630,
#   '成交金額': 241494431,
#   '最低價': 34.5,
#   '最高價': 36.2,
#   '成交筆數': 4409},
#  {'證券名稱': '慧友',
#   '成交股數': 254477,
#   '成交金額': 1887281,
#   '最低價': 7.1,
#   '最高價': 7.47,
#   '成交筆數': 52},
#  {'證券名稱': '建國',
#   '成交股數': 937542,
#   '成交金額': 7392529,
#   '最低價': 7.71,
#   '最高價': 8.26,
#   '成交筆數': 294},
#  {'證券名稱': '隆大',
#   '成交股數': 990603,
#   '成交金額': 11223451,
#   '最低價': 11.1,
#   '最高價': 11.6,
#   '成交筆數': 488},
#  {'證券名稱': '工信',
#   '成交股數': 2497213,
#   '成交金額': 15751652,
#   '最低價': 6.12,
#   '最高價': 6.64,
#   '成交筆數': 903},
#  {'證券名稱': '遠雄',
#   '成交股數': 1648604,
#   '成交金額': 53333377,
#   '最低價': 31.95,
#   '最高價': 32.8,
#   '成交筆數': 1088},
#  {'證券名稱': '順天',
#   '成交股數': 141400,
#   '成交金額': 2413739,
#   '最低價': 16.7,
#   '最高價': 17.5,
#   '成交筆數': 114},
#  {'證券名稱': '鄉林',
#   '成交股數': 1261084,
#   '成交金額': 9515842,
#   '最低價': 7.31,
#   '最高價': 7.83,
#   '成交筆數': 536},
#  {'證券名稱': '皇鼎',
#   '成交股數': 146292,
#   '成交金額': 2085081,
#   '最低價': 14.05,
#   '最高價': 14.5,
#   '成交筆數': 81},
#  {'證券名稱': '長虹',
#   '成交股數': 908301,
#   '成交金額': 63242739,
#   '最低價': 67.8,
#   '最高價': 70.9,
#   '成交筆數': 630},
#  {'證券名稱': '東明-KY',
#   '成交股數': 12000,
#   '成交金額': 317950,
#   '最低價': 24.8,
#   '最高價': 27.8,
#   '成交筆數': 12},
#  {'證券名稱': '遠雄港',
#   '成交股數': 1485031,
#   '成交金額': 26705114,
#   '最低價': 17.6,
#   '最高價': 18.35,
#   '成交筆數': 485},
#  {'證券名稱': '四維航',
#   '成交股數': 807890,
#   '成交金額': 4125820,
#   '最低價': 5.01,
#   '最高價': 5.2,
#   '成交筆數': 318},
#  {'證券名稱': '鳳凰',
#   '成交股數': 431927,
#   '成交金額': 10163483,
#   '最低價': 23.15,
#   '最高價': 25.65,
#   '成交筆數': 352},
#  {'證券名稱': '中租-KY',
#   '成交股數': 11706164,
#   '成交金額': 1020155493,
#   '最低價': 86.2,
#   '最高價': 89.0,
#   '成交筆數': 6359},
#  {'證券名稱': '上海商銀',
#   '成交股數': 11271026,
#   '成交金額': 429547467,
#   '最低價': 37.2,
#   '最高價': 39.1,
#   '成交筆數': 5071},
#  {'證券名稱': '合庫金',
#   '成交股數': 47781712,
#   '成交金額': 821741554,
#   '最低價': 17.1,
#   '最高價': 17.4,
#   '成交筆數': 14441},
#  {'證券名稱': '台南-KY',
#   '成交股數': 18000,
#   '成交金額': 301000,
#   '最低價': 16.4,
#   '最高價': 17.05,
#   '成交筆數': 16},
#  {'證券名稱': '大洋-KY',
#   '成交股數': 382500,
#   '成交金額': 6438300,
#   '最低價': 16.25,
#   '最高價': 17.45,
#   '成交筆數': 245},
#  {'證券名稱': '群益證',
#   '成交股數': 3648468,
#   '成交金額': 30375571,
#   '最低價': 8.28,
#   '最高價': 8.43,
#   '成交筆數': 1133},
#  {'證券名稱': '群益期',
#   '成交股數': 573227,
#   '成交金額': 19902573,
#   '最低價': 34.4,
#   '最高價': 35.45,
#   '成交筆數': 390},
#  {'證券名稱': '競國',
#   '成交股數': 791006,
#   '成交金額': 14435664,
#   '最低價': 17.7,
#   '最高價': 19.1,
#   '成交筆數': 485},
#  {'證券名稱': '聚碩',
#   '成交股數': 1160352,
#   '成交金額': 37087239,
#   '最低價': 31.5,
#   '最高價': 32.45,
#   '成交筆數': 788},
#  {'證券名稱': '鎰勝',
#   '成交股數': 326000,
#   '成交金額': 12578300,
#   '最低價': 38.4,
#   '最高價': 38.8,
#   '成交筆數': 209},
#  {'證券名稱': '彩晶',
#   '成交股數': 18451286,
#   '成交金額': 98578238,
#   '最低價': 5.17,
#   '最高價': 5.45,
#   '成交筆數': 4456},
#  {'證券名稱': '迎廣',
#   '成交股數': 15000,
#   '成交金額': 179950,
#   '最低價': 11.5,
#   '最高價': 12.4,
#   '成交筆數': 15},
#  {'證券名稱': '達運',
#   '成交股數': 2507458,
#   '成交金額': 22630570,
#   '最低價': 8.51,
#   '最高價': 9.36,
#   '成交筆數': 1188},
#  {'證券名稱': '上福',
#   '成交股數': 92216,
#   '成交金額': 2307120,
#   '最低價': 24.9,
#   '最高價': 25.25,
#   '成交筆數': 80},
#  {'證券名稱': '鈞泰',
#   '成交股數': 32244,
#   '成交金額': 105642,
#   '最低價': 3.16,
#   '最高價': 3.49,
#   '成交筆數': 35},
#  {'證券名稱': '金橋',
#   '成交股數': 83013,
#   '成交金額': 552506,
#   '最低價': 6.5,
#   '最高價': 6.7,
#   '成交筆數': 48},
#  {'證券名稱': '富爾特',
#   '成交股數': 307187,
#   '成交金額': 4936819,
#   '最低價': 15.9,
#   '最高價': 16.2,
#   '成交筆數': 183},
#  {'證券名稱': '亞翔',
#   '成交股數': 762002,
#   '成交金額': 16303446,
#   '最低價': 21.1,
#   '最高價': 21.8,
#   '成交筆數': 396},
#  {'證券名稱': '柏承',
#   '成交股數': 1040057,
#   '成交金額': 14741798,
#   '最低價': 13.9,
#   '最高價': 14.45,
#   '成交筆數': 562},
#  {'證券名稱': '友勁',
#   '成交股數': 309861,
#   '成交金額': 1353370,
#   '最低價': 4.19,
#   '最高價': 4.5,
#   '成交筆數': 101},
#  {'證券名稱': '百一',
#   '成交股數': 128210,
#   '成交金額': 569614,
#   '最低價': 4.32,
#   '最高價': 4.62,
#   '成交筆數': 79},
#  {'證券名稱': '嘉聯益',
#   '成交股數': 8097829,
#   '成交金額': 181019904,
#   '最低價': 21.5,
#   '最高價': 23.1,
#   '成交筆數': 3901},
#  {'證券名稱': '鈞寶',
#   '成交股數': 366050,
#   '成交金額': 6454745,
#   '最低價': 17.1,
#   '最高價': 17.95,
#   '成交筆數': 294},
#  {'證券名稱': '華興',
#   '成交股數': 280000,
#   '成交金額': 1386940,
#   '最低價': 4.82,
#   '最高價': 5.1,
#   '成交筆數': 94},
#  {'證券名稱': '捷泰',
#   '成交股數': 533199,
#   '成交金額': 8837079,
#   '最低價': 15.6,
#   '最高價': 17.7,
#   '成交筆數': 232},
#  {'證券名稱': '凌華',
#   '成交股數': 1062639,
#   '成交金額': 57606710,
#   '最低價': 52.3,
#   '最高價': 56.5,
#   '成交筆數': 747},
#  {'證券名稱': '宏齊',
#   '成交股數': 620098,
#   '成交金額': 6268967,
#   '最低價': 9.91,
#   '最高價': 10.3,
#   '成交筆數': 353},
#  {'證券名稱': '互億',
#   '成交股數': 37000,
#   '成交金額': 700300,
#   '最低價': 18.7,
#   '最高價': 19.2,
#   '成交筆數': 30},
#  {'證券名稱': '瑞儀',
#   '成交股數': 4755555,
#   '成交金額': 383347819,
#   '最低價': 77.3,
#   '最高價': 83.8,
#   '成交筆數': 3351},
#  {'證券名稱': '達麗',
#   '成交股數': 661088,
#   '成交金額': 15514893,
#   '最低價': 23.15,
#   '最高價': 23.95,
#   '成交筆數': 323},
#  {'證券名稱': '關貿',
#   '成交股數': 501458,
#   '成交金額': 18654382,
#   '最低價': 36.1,
#   '最高價': 38.1,
#   '成交筆數': 345},
#  {'證券名稱': '大豐電',
#   '成交股數': 187700,
#   '成交金額': 7231069,
#   '最低價': 38.2,
#   '最高價': 38.7,
#   '成交筆數': 141},
#  {'證券名稱': '豐藝',
#   '成交股數': 1769525,
#   '成交金額': 50857402,
#   '最低價': 28.35,
#   '最高價': 29.4,
#   '成交筆數': 1120},
#  {'證券名稱': '精成科',
#   '成交股數': 2346400,
#   '成交金額': 26689789,
#   '最低價': 11.2,
#   '最高價': 11.7,
#   '成交筆數': 872},
#  {'證券名稱': '巨路',
#   '成交股數': 290768,
#   '成交金額': 16331498,
#   '最低價': 55.4,
#   '最高價': 57.0,
#   '成交筆數': 267},
#  {'證券名稱': '帆宣',
#   '成交股數': 1510527,
#   '成交金額': 81314033,
#   '最低價': 52.5,
#   '最高價': 55.0,
#   '成交筆數': 1176},
#  {'證券名稱': '佳必琪',
#   '成交股數': 1051966,
#   '成交金額': 23420862,
#   '最低價': 21.3,
#   '最高價': 23.4,
#   '成交筆數': 544},
#  {'證券名稱': '亞弘電',
#   '成交股數': 183000,
#   '成交金額': 5742850,
#   '最低價': 30.8,
#   '最高價': 32.1,
#   '成交筆數': 150},
#  {'證券名稱': '盛群',
#   '成交股數': 2057500,
#   '成交金額': 127498900,
#   '最低價': 60.3,
#   '最高價': 63.2,
#   '成交筆數': 1618},
#  {'證券名稱': '詮欣',
#   '成交股數': 45040,
#   '成交金額': 882987,
#   '最低價': 19.35,
#   '最高價': 19.85,
#   '成交筆數': 42},
#  {'證券名稱': '飛捷',
#   '成交股數': 426143,
#   '成交金額': 24964936,
#   '最低價': 57.1,
#   '最高價': 59.7,
#   '成交筆數': 357},
#  {'證券名稱': '今國光',
#   '成交股數': 803269,
#   '成交金額': 12701235,
#   '最低價': 15.35,
#   '最高價': 16.25,
#   '成交筆數': 519},
#  {'證券名稱': '聯茂',
#   '成交股數': 13578297,
#   '成交金額': 1602083843,
#   '最低價': 112.5,
#   '最高價': 121.0,
#   '成交筆數': 8021},
#  {'證券名稱': '精誠',
#   '成交股數': 1127229,
#   '成交金額': 81865710,
#   '最低價': 71.5,
#   '最高價': 73.8,
#   '成交筆數': 865},
#  {'證券名稱': '和椿',
#   '成交股數': 277193,
#   '成交金額': 2865320,
#   '最低價': 10.25,
#   '最高價': 10.45,
#   '成交筆數': 124},
#  {'證券名稱': '居易',
#   '成交股數': 195050,
#   '成交金額': 4521310,
#   '最低價': 22.6,
#   '最高價': 23.75,
#   '成交筆數': 176},
#  {'證券名稱': '聚鼎',
#   '成交股數': 309597,
#   '成交金額': 15888902,
#   '最低價': 50.6,
#   '最高價': 52.3,
#   '成交筆數': 271},
#  {'證券名稱': '天瀚',
#   '成交股數': 49745,
#   '成交金額': 98375,
#   '最低價': 1.98,
#   '最高價': 1.98,
#   '成交筆數': 6},
#  {'證券名稱': '光鼎',
#   '成交股數': 914027,
#   '成交金額': 5744202,
#   '最低價': 6.22,
#   '最高價': 6.37,
#   '成交筆數': 372},
#  {'證券名稱': '超眾',
#   '成交股數': 3699713,
#   '成交金額': 677057257,
#   '最低價': 175.5,
#   '最高價': 189.0,
#   '成交筆數': 2874},
#  {'證券名稱': '華孚',
#   '成交股數': 469561,
#   '成交金額': 3757188,
#   '最低價': 7.9,
#   '最高價': 8.34,
#   '成交筆數': 235},
#  {'證券名稱': '力成',
#   '成交股數': 7785459,
#   '成交金額': 608329484,
#   '最低價': 75.8,
#   '最高價': 81.9,
#   '成交筆數': 5055},
#  {'證券名稱': '迅杰',
#   '成交股數': 178009,
#   '成交金額': 1104484,
#   '最低價': 6.05,
#   '最高價': 6.32,
#   '成交筆數': 101},
#  {'證券名稱': '定穎',
#   '成交股數': 4660514,
#   '成交金額': 62827131,
#   '最低價': 13.0,
#   '最高價': 13.95,
#   '成交筆數': 1945},
#  {'證券名稱': '矽格',
#   '成交股數': 5780590,
#   '成交金額': 179486997,
#   '最低價': 30.2,
#   '最高價': 31.8,
#   '成交筆數': 3156},
#  {'證券名稱': '台郡',
#   '成交股數': 6239041,
#   '成交金額': 562066939,
#   '最低價': 87.0,
#   '最高價': 91.9,
#   '成交筆數': 3775},
#  {'證券名稱': '同欣電',
#   '成交股數': 3707478,
#   '成交金額': 376502566,
#   '最低價': 98.8,
#   '最高價': 105.0,
#   '成交筆數': 2560},
#  {'證券名稱': '宏正',
#   '成交股數': 313000,
#   '成交金額': 24408100,
#   '最低價': 77.2,
#   '最高價': 79.5,
#   '成交筆數': 256},
#  {'證券名稱': '台表科',
#   '成交股數': 7381320,
#   '成交金額': 475054440,
#   '最低價': 61.4,
#   '最高價': 67.4,
#   '成交筆數': 5273},
#  {'證券名稱': '全國電',
#   '成交股數': 242350,
#   '成交金額': 14995728,
#   '最低價': 61.1,
#   '最高價': 62.5,
#   '成交筆數': 216},
#  {'證券名稱': '康舒',
#   '成交股數': 2436920,
#   '成交金額': 42443846,
#   '最低價': 17.0,
#   '最高價': 17.8,
#   '成交筆數': 1314},
#  {'證券名稱': '淳安',
#   '成交股數': 587950,
#   '成交金額': 8054629,
#   '最低價': 13.4,
#   '最高價': 14.3,
#   '成交筆數': 299},
#  {'證券名稱': '啟碁',
#   '成交股數': 3088068,
#   '成交金額': 158439334,
#   '最低價': 50.0,
#   '最高價': 53.2,
#   '成交筆數': 1973},
#  {'證券名稱': '聯嘉',
#   '成交股數': 1727515,
#   '成交金額': 27682411,
#   '最低價': 15.75,
#   '最高價': 16.4,
#   '成交筆數': 838},
#  {'證券名稱': '華上',
#   '成交股數': 64977,
#   '成交金額': 101392,
#   '最低價': 1.55,
#   '最高價': 1.66,
#   '成交筆數': 69},
#  {'證券名稱': '悅城',
#   '成交股數': 88000,
#   '成交金額': 970450,
#   '最低價': 10.7,
#   '最高價': 11.3,
#   '成交筆數': 50},
#  {'證券名稱': '旭隼',
#   '成交股數': 357071,
#   '成交金額': 218395526,
#   '最低價': 605.0,
#   '最高價': 625.0,
#   '成交筆數': 206},
#  {'證券名稱': '群電',
#   '成交股數': 1478185,
#   '成交金額': 69114631,
#   '最低價': 46.05,
#   '最高價': 47.7,
#   '成交筆數': 1203},
#  {'證券名稱': '樺漢',
#   '成交股數': 2101533,
#   '成交金額': 312628318,
#   '最低價': 142.0,
#   '最高價': 158.0,
#   '成交筆數': 1828},
#  {'證券名稱': '矽力-KY',
#   '成交股數': 1669948,
#   '成交金額': 1280011872,
#   '最低價': 712.0,
#   '最高價': 804.0,
#   '成交筆數': 1624},
#  {'證券名稱': '瑞祺電通',
#   '成交股數': 7605468,
#   '成交金額': 893830852,
#   '最低價': 112.0,
#   '最高價': 121.0,
#   '成交筆數': 5876},
#  {'證券名稱': '光麗-KY',
#   '成交股數': 95000,
#   '成交金額': 1987150,
#   '最低價': 20.5,
#   '最高價': 21.05,
#   '成交筆數': 20},
#  {'證券名稱': '光聖',
#   '成交股數': 113712,
#   '成交金額': 4089854,
#   '最低價': 34.6,
#   '最高價': 36.5,
#   '成交筆數': 77},
#  {'證券名稱': '元晶',
#   '成交股數': 1448863,
#   '成交金額': 6924162,
#   '最低價': 4.68,
#   '最高價': 4.85,
#   '成交筆數': 464},
#  {'證券名稱': '鈺邦',
#   '成交股數': 204035,
#   '成交金額': 4609071,
#   '最低價': 22.1,
#   '最高價': 23.1,
#   '成交筆數': 155},
#  {'證券名稱': '訊芯-KY',
#   '成交股數': 2030400,
#   '成交金額': 163803500,
#   '最低價': 78.0,
#   '最高價': 82.7,
#   '成交筆數': 1522},
#  {'證券名稱': '康友-KY',
#   '成交股數': 1606773,
#   '成交金額': 237524812,
#   '最低價': 142.5,
#   '最高價': 152.5,
#   '成交筆數': 1259},
#  {'證券名稱': 'GIS-KY',
#   '成交股數': 3068246,
#   '成交金額': 222610794,
#   '最低價': 70.2,
#   '最高價': 74.9,
#   '成交筆數': 2194},
#  {'證券名稱': '台數科',
#   '成交股數': 19585,
#   '成交金額': 2139435,
#   '最低價': 107.0,
#   '最高價': 111.0,
#   '成交筆數': 20},
#  {'證券名稱': '安集',
#   '成交股數': 329000,
#   '成交金額': 5666100,
#   '最低價': 17.1,
#   '最高價': 17.5,
#   '成交筆數': 135},
#  {'證券名稱': '晶碩',
#   '成交股數': 171600,
#   '成交金額': 17151900,
#   '最低價': 96.4,
#   '最高價': 104.0,
#   '成交筆數': 152},
#  {'證券名稱': '南六',
#   '成交股數': 1462320,
#   '成交金額': 206382800,
#   '最低價': 138.0,
#   '最高價': 145.0,
#   '成交筆數': 1132},
#  {'證券名稱': '台塑化',
#   '成交股數': 7848301,
#   '成交金額': 537013960,
#   '最低價': 67.8,
#   '最高價': 69.0,
#   '成交筆數': 4706},
#  {'證券名稱': '捷敏-KY',
#   '成交股數': 335409,
#   '成交金額': 15525514,
#   '最低價': 45.1,
#   '最高價': 47.3,
#   '成交筆數': 254},
#  {'證券名稱': '愛普',
#   '成交股數': 5102351,
#   '成交金額': 430305737,
#   '最低價': 78.8,
#   '最高價': 88.2,
#   '成交筆數': 3660},
#  {'證券名稱': '晶心科',
#   '成交股數': 610681,
#   '成交金額': 47112394,
#   '最低價': 73.1,
#   '最高價': 79.7,
#   '成交筆數': 528},
#  {'證券名稱': '泰福-KY',
#   '成交股數': 1102216,
#   '成交金額': 30938469,
#   '最低價': 26.8,
#   '最高價': 30.25,
#   '成交筆數': 670},
#  {'證券名稱': '易華電',
#   '成交股數': 2206201,
#   '成交金額': 101139775,
#   '最低價': 44.25,
#   '最高價': 47.65,
#   '成交筆數': 1553},
#  {'證券名稱': '興能高',
#   '成交股數': 3729614,
#   '成交金額': 115181847,
#   '最低價': 29.65,
#   '最高價': 32.8,
#   '成交筆數': 2643},
#  {'證券名稱': '虹揚-KY',
#   '成交股數': 60000,
#   '成交金額': 933400,
#   '最低價': 15.1,
#   '最高價': 16.4,
#   '成交筆數': 48},
#  {'證券名稱': '研揚',
#   '成交股數': 115041,
#   '成交金額': 6936692,
#   '最低價': 59.7,
#   '最高價': 60.9,
#   '成交筆數': 82},
#  {'證券名稱': '鋼聯',
#   '成交股數': 142268,
#   '成交金額': 7501701,
#   '最低價': 51.0,
#   '最高價': 55.0,
#   '成交筆數': 106},
#  {'證券名稱': '申豐',
#   '成交股數': 466301,
#   '成交金額': 33511477,
#   '最低價': 68.0,
#   '最高價': 75.0,
#   '成交筆數': 396},
#  {'證券名稱': '動力-KY',
#   '成交股數': 375000,
#   '成交金額': 12135750,
#   '最低價': 31.35,
#   '最高價': 33.1,
#   '成交筆數': 283},
#  {'證券名稱': '和潤企業',
#   '成交股數': 2063539,
#   '成交金額': 128593018,
#   '最低價': 62.0,
#   '最高價': 63.2,
#   '成交筆數': 1294},
#  {'證券名稱': '帝寶',
#   '成交股數': 307436,
#   '成交金額': 12949329,
#   '最低價': 41.0,
#   '最高價': 43.5,
#   '成交筆數': 228},
#  {'證券名稱': '必應',
#   '成交股數': 60614,
#   '成交金額': 1605816,
#   '最低價': 24.75,
#   '最高價': 28.2,
#   '成交筆數': 56},
#  {'證券名稱': '基士德-KY',
#   '成交股數': 67500,
#   '成交金額': 3449050,
#   '最低價': 50.4,
#   '最高價': 51.9,
#   '成交筆數': 53},
#  {'證券名稱': '科定',
#   '成交股數': 182969,
#   '成交金額': 6515946,
#   '最低價': 34.8,
#   '最高價': 36.0,
#   '成交筆數': 143},
#  {'證券名稱': '羅麗芬-KY',
#   '成交股數': 156120,
#   '成交金額': 15063900,
#   '最低價': 94.3,
#   '最高價': 98.5,
#   '成交筆數': 148},
#  {'證券名稱': '中揚光',
#   '成交股數': 1359229,
#   '成交金額': 68410071,
#   '最低價': 48.3,
#   '最高價': 52.2,
#   '成交筆數': 893},
#  {'證券名稱': '緯穎',
#   '成交股數': 2248997,
#   '成交金額': 1514950077,
#   '最低價': 641.0,
#   '最高價': 695.0,
#   '成交筆數': 2146},
#  {'證券名稱': '復盛應用',
#   '成交股數': 836300,
#   '成交金額': 118487448,
#   '最低價': 138.5,
#   '最高價': 146.0,
#   '成交筆數': 794},
#  {'證券名稱': '三能-KY',
#   '成交股數': 121000,
#   '成交金額': 3839100,
#   '最低價': 30.85,
#   '最高價': 32.8,
#   '成交筆數': 77},
#  ...]

# %%
float(''.join('3,600.00'.split(',')))
# Out:
# 3600.0

# %%
float(''.join('600.00'.split(',')))
# Out:
# 600.0
