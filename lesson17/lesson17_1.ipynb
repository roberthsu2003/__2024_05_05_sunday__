# %%
import numpy as np
import pandas as pd
students = np.random.randint(50,101,size=(50,5))
stu = pd.DataFrame(students,
             columns=['國文','英文','數學','地理','歷史'],
             index=[f'第{i}號' for i in range(1,51)]
             )
stu

# %%
#陣列運算,使用數學運算子
stu['國文'] + stu['數學']

# %%
#陣列運算,使用比較運算子
stu['國文'] <= 60

# %%
#Series執行統計的方法
stu['國文'].sum()

# %%
#使用numpy統計方法
import numpy as np
np.sum(stu['國文'])

# %%
#DataFrame執行統計的方法
stu
stu['總分'] = stu.iloc[:,:5].sum(axis=1)
stu['平均'] = stu.iloc[:,:5].mean(axis=1)
stu

# %%
stu
stu['總分'] = np.sum(stu.iloc[:,:5],axis=1)
stu['平均'] = np.mean(stu.iloc[:,:5],axis=1)
stu

# %%
#使用seires的索引和index name
stu['總分'].iloc[0]
stu['總分']['第1號']

# %%
#Series sort
stu['總分'].sort_values()
sorted_s = stu['總分'].sort_values(ascending=False)

# %%
#使用sort_values(),取出前5分
sorted_s[:5]
# Out:
# 第40號    457
# 第41號    451
# 第15號    435
# 第33號    414
# 第18號    408
# Name: 總分, dtype: int64

# %%
#DataFrame sorted
sorted_df = stu.sort_values(by='總分',ascending=False)
sorted_df[:5]
# Out:
#       國文  英文   數學  地理  歷史   總分    平均
# 第40號  92  80  100  92  93  457  91.4
# 第41號  73  96   94  91  97  451  90.2
# 第15號  98  92   97  89  59  435  87.0
# 第33號  95  90   81  84  64  414  82.8
# 第18號  98  98   63  60  89  408  81.6

# %%
sorted_df['排名'] = sorted_df['平均'].rank(ascending=False,method='first')
sorted_df
# Out:
#        國文  英文   數學  地理   歷史   總分    平均    排名
# 第40號   92  80  100  92   93  457  91.4   1.0
# 第41號   73  96   94  91   97  451  90.2   2.0
# 第15號   98  92   97  89   59  435  87.0   3.0
# 第33號   95  90   81  84   64  414  82.8   4.0
# 第18號   98  98   63  60   89  408  81.6   5.0
# 第39號   81  86   78  63   99  407  81.4   6.0
# 第9號    97  76   93  82   51  399  79.8   7.0
# 第31號   87  60   84  74   93  398  79.6   8.0
# 第20號   62  99   61  85   85  392  78.4   9.0
# 第17號   82  77   83  68   79  389  77.8  10.0
# 第50號   78  99   61  83   67  388  77.6  11.0
# 第8號    80  57   75  88   88  388  77.6  12.0
# 第7號    70  98  100  69   50  387  77.4  13.0
# 第22號   97  88   56  50   95  386  77.2  14.0
# 第49號   89  74   91  67   64  385  77.0  15.0
# 第14號   82  84   79  59   79  383  76.6  16.0
# 第3號    55  90   61  82   95  383  76.6  17.0
# 第19號   62  88   99  60   74  383  76.6  18.0
# 第32號   58  66   81  84   90  379  75.8  19.0
