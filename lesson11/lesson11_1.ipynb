# %%
with open('aqx_p_488.json',encoding='utf-8') as file:
    print(file.read())
# Out:
# {
#     "fields": [
#         {
#             "id": "sitename",
#             "type": "text",
#             "info": {
#                 "label": "測站名稱"
#             }
#         },
#         {
#             "id": "county",
#             "type": "text",
#             "info": {
#                 "label": "縣市"
#             }
#         },
#         {
#             "id": "aqi",
#             "type": "text",
#             "info": {
#                 "label": "空氣品質指標"
#             }
#         },
#         {
#             "id": "pollutant",
#             "type": "text",
#             "info": {
#                 "label": "空氣污染指標物"
#             }
#         },
#         {
#             "id": "status",
#             "type": "text",
#             "info": {
#                 "label": "狀態"
#             }
#         },
#         {
#             "id": "so2",
#             "type": "text",
#             "info": {
#                 "label": "二氧化硫[ppb]"
#             }
#         },
#         {
# ...
